# %%
import sys
sys.path.append("..")
from config import *
from scripts.measurement_devices import *
from scripts.gaussian_process_sawei import GPSawei
from scripts.run_active_learning import *
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
from scripts.plotting_MAE import *
from scripts.evenly_spaced_points import *

# %%
df = pd.read_csv(DATASET_10311_Au_Pd_Pt_Rh_Ru_RT)

init_indices = select_paper_style_points(df, x_col='x', y_col='y',  inner_step=3)

base_dir = MAE_PLOT
filename = "initialization_strategies_10311.pdf"
save_path = os.path.join(base_dir, filename)

plot_initialization_strategies(
    csv_path=DATASET_10311_Au_Pd_Pt_Rh_Ru_RT,
    all_init_strategies={
        "Four-point probe measurement": init_indices,
        
        "Min Comp": [
            199, 11, 23, 295, 340
        ],
        
        "Cent_sat_high": [
            144, 168, 80, 290, 270
        ],
        
        "Min Comp + Cent_sat_high": [
            144, 168, 80, 290, 270,
            199, 11, 23, 295, 340
        ]
    }, output_path=save_path
)
# Out:
#  c:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\notebook\..\scripts\plotting_MAE.py:433: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# Define all datasets
datasets = [
    DATASET_10272_Ag_Au_Pd_RT,
    DATASET_10275_Ag_Au_Pd_Pt_Rh_RT,
    DATASET_10304_Au_Pd_Pt_Rh_RT,
    DATASET_10311_Au_Pd_Pt_Rh_Ru_RT,
    DATASET_10403_Ag_Au_Cu_Pd_Pt_RT, 
    DATASET_10402_Ag_Au_Pd_Pt_RT,
    DATASET_10399_Au_Cu_Pd_Pt_RT,
    DATASET_10374_Ir_Pd_Pt_Rh_Ru
]

# Config
init_indices = init_indices  
target_col = "Resistance"
excluded_cols = ["ID", "x", "y"]
max_iter = 100

# Define GP variants and output paths
gp_class_dict = {
    "GPBasic": GPBasic,
    "GPSawei": GPSawei
}

output_base_path_dict = {
    "GPBasic": EVENLY_PATH_Uncertainty,
    "GPSawei": EVENLY_PATH_Sawei
}

# Store summaries
summary_results_dict = {}

# Run on all datasets
for dataset_path in datasets:
    run_active_learning_multiple_gp(
        dataset_path=dataset_path,
        init_indices=init_indices,
        target_col=target_col,
        excluded_cols=excluded_cols,
        max_iter=max_iter,
        output_base_path_dict=output_base_path_dict,
        gp_class_dict=gp_class_dict,
        summary_results_dict=summary_results_dict
    )

# Save summary tables for each GP variant
for gp_name, summary_data in summary_results_dict.items():
    summary_df = pd.DataFrame(summary_data)
    summary_path = os.path.join(output_base_path_dict[gp_name], f"summary_stopping_iterations_{gp_name}.csv")
    summary_df.to_csv(summary_path, index=False)
    print(f"\nSaved summary for {gp_name} to: {summary_path}")
# Out:
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# --- Processing: 10272_Ag-Au-Pd_RT ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 3), y = (9, 1), len(variables) = 3
# Iteration 1: MAE = 0.02135
# Iteration 2: MAE = 0.02094
# Iteration 3: MAE = 0.02086
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 4: MAE = 0.02207
# Iteration 5: MAE = 0.02101
# Iteration 6: MAE = 0.02082
# Iteration 7: MAE = 0.02083
# Iteration 8: MAE = 0.02115
# Iteration 9: MAE = 0.02051
# Iteration 10: MAE = 0.02115
# Iteration 11: MAE = 0.02110
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 12: MAE = 0.02099
# Iteration 13: MAE = 0.01756
# Iteration 14: MAE = 0.00989
# Iteration 15: MAE = 0.00982
# Iteration 16: MAE = 0.00992
# Iteration 17: MAE = 0.01012
# Iteration 18: MAE = 0.01053
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 19: MAE = 0.01019
# Iteration 20: MAE = 0.00884
# Iteration 21: MAE = 0.00767
# Iteration 22: MAE = 0.00757
# Iteration 23: MAE = 0.00722
# Iteration 24: MAE = 0.00648
# Iteration 25: MAE = 0.00648
# Iteration 26: MAE = 0.00639
# Iteration 27: MAE = 0.00630
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 28: MAE = 0.00613
# Iteration 29: MAE = 0.00589
# Iteration 30: MAE = 0.00595
# Check stopping: MAE = 0.00595, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00602
# Check stopping: MAE = 0.00602, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00588
# Check stopping: MAE = 0.00588, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00574
# Check stopping: MAE = 0.00574, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 34: MAE = 0.00570
# Check stopping: MAE = 0.00570, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00561
# Check stopping: MAE = 0.00561, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00495
# Check stopping: MAE = 0.00495, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 36 due to stopping condition.
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10272_Ag-Au-Pd_RT
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 3), y = (9, 1), len(variables) = 3
# Iteration 1: MAE = 0.02135
# Iteration 2: MAE = 0.02094
# Iteration 3: MAE = 0.02086
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 4: MAE = 0.02207
# Iteration 5: MAE = 0.02101
# Iteration 6: MAE = 0.02082
# Iteration 7: MAE = 0.02083
# Iteration 8: MAE = 0.02115
# Iteration 9: MAE = 0.02051
# Iteration 10: MAE = 0.02115
# Iteration 11: MAE = 0.02110
# Iteration 12: MAE = 0.02099
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 13: MAE = 0.01756
# Iteration 14: MAE = 0.00989
# Iteration 15: MAE = 0.00982
# Iteration 16: MAE = 0.00992
# Iteration 17: MAE = 0.01012
# Iteration 18: MAE = 0.01053
# Iteration 19: MAE = 0.01019
# Iteration 20: MAE = 0.00884
# Iteration 21: MAE = 0.00767
# Iteration 22: MAE = 0.00757
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 23: MAE = 0.00722
# Iteration 24: MAE = 0.00648
# Iteration 25: MAE = 0.00648
# Iteration 26: MAE = 0.00639
# Iteration 27: MAE = 0.00630
# Iteration 28: MAE = 0.00613
# Iteration 29: MAE = 0.00589
# Iteration 30: MAE = 0.00595
# Check stopping: MAE = 0.00595, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00602
# Check stopping: MAE = 0.00602, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 32: MAE = 0.00588
# Check stopping: MAE = 0.00588, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00574
# Check stopping: MAE = 0.00574, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00570
# Check stopping: MAE = 0.00570, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00561
# Check stopping: MAE = 0.00561, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00495
# Check stopping: MAE = 0.00495, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 36 due to stopping condition.
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10272_Ag-Au-Pd_RT
#
# --- Processing: 10275_Ag-Au-Pd-Pt-Rh_RT ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 1: MAE = 0.01629
# Iteration 2: MAE = 0.01396
# Iteration 3: MAE = 0.01442
# Iteration 4: MAE = 0.01448
# Iteration 5: MAE = 0.01428
# Iteration 6: MAE = 0.01188
# Iteration 7: MAE = 0.00973
# Iteration 8: MAE = 0.00966
# Iteration 9: MAE = 0.00787
# Iteration 10: MAE = 0.00795
# Iteration 11: MAE = 0.00807
# Iteration 12: MAE = 0.00776
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 13: MAE = 0.00761
# Iteration 14: MAE = 0.00747
# Iteration 15: MAE = 0.00734
# Iteration 16: MAE = 0.00733
# Iteration 17: MAE = 0.00744
# Iteration 18: MAE = 0.00742
# Iteration 19: MAE = 0.00744
# Iteration 20: MAE = 0.00708
# Iteration 21: MAE = 0.00666
# Iteration 22: MAE = 0.00657
# Iteration 23: MAE = 0.00656
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 24: MAE = 0.00731
# Iteration 25: MAE = 0.00725
# Iteration 26: MAE = 0.00729
# Iteration 27: MAE = 0.00721
# Iteration 28: MAE = 0.00720
# Iteration 29: MAE = 0.00721
# Iteration 30: MAE = 0.00728
# Check stopping: MAE = 0.00728, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 31: MAE = 0.00727
# Check stopping: MAE = 0.00727, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00719
# Check stopping: MAE = 0.00719, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00721
# Check stopping: MAE = 0.00721, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00723
# Check stopping: MAE = 0.00723, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00721
# Check stopping: MAE = 0.00721, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00698
# Check stopping: MAE = 0.00698, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 38: MAE = 0.00694
# Check stopping: MAE = 0.00694, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00692
# Check stopping: MAE = 0.00692, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00691
# Check stopping: MAE = 0.00691, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00691
# Check stopping: MAE = 0.00691, Cov Gradient Stable = True
# Iteration 42: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = True
# Iteration 43: MAE = 0.00699
# Check stopping: MAE = 0.00699, Cov Gradient Stable = True
# Iteration 44: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = True
# Iteration 45: MAE = 0.00701
# Check stopping: MAE = 0.00701, Cov Gradient Stable = True
# Iteration 46: MAE = 0.00692
# Check stopping: MAE = 0.00692, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 47: MAE = 0.00692
# Check stopping: MAE = 0.00692, Cov Gradient Stable = True
# Iteration 48: MAE = 0.00679
# Check stopping: MAE = 0.00679, Cov Gradient Stable = True
# Iteration 49: MAE = 0.00674
# Check stopping: MAE = 0.00674, Cov Gradient Stable = True
# Iteration 50: MAE = 0.00679
# Check stopping: MAE = 0.00679, Cov Gradient Stable = True
# Iteration 51: MAE = 0.00670
# Check stopping: MAE = 0.00670, Cov Gradient Stable = True
# Iteration 52: MAE = 0.00671
# Check stopping: MAE = 0.00671, Cov Gradient Stable = True
# Iteration 53: MAE = 0.00673
# Check stopping: MAE = 0.00673, Cov Gradient Stable = True
# Iteration 54: MAE = 0.00669
# Check stopping: MAE = 0.00669, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 55: MAE = 0.00666
# Check stopping: MAE = 0.00666, Cov Gradient Stable = True
# Iteration 56: MAE = 0.00632
# Check stopping: MAE = 0.00632, Cov Gradient Stable = True
# Iteration 57: MAE = 0.00628
# Check stopping: MAE = 0.00628, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 58: MAE = 0.00620
# Check stopping: MAE = 0.00620, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00619
# Check stopping: MAE = 0.00619, Cov Gradient Stable = True
# Iteration 60: MAE = 0.00614
# Check stopping: MAE = 0.00614, Cov Gradient Stable = True
# Iteration 61: MAE = 0.00616
# Check stopping: MAE = 0.00616, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 62: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = True
# Iteration 63: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = True
# Iteration 64: MAE = 0.00596
# Check stopping: MAE = 0.00596, Cov Gradient Stable = True
# Iteration 65: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 66: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = True
# Iteration 67: MAE = 0.00580
# Check stopping: MAE = 0.00580, Cov Gradient Stable = True
# Iteration 68: MAE = 0.00571
# Check stopping: MAE = 0.00571, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 69: MAE = 0.00570
# Check stopping: MAE = 0.00570, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00569
# Check stopping: MAE = 0.00569, Cov Gradient Stable = True
# Iteration 71: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = True
# Iteration 72: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 73: MAE = 0.00565
# Check stopping: MAE = 0.00565, Cov Gradient Stable = True
# Iteration 74: MAE = 0.00557
# Check stopping: MAE = 0.00557, Cov Gradient Stable = True
# Iteration 75: MAE = 0.00554
# Check stopping: MAE = 0.00554, Cov Gradient Stable = True
# Iteration 76: MAE = 0.00553
# Check stopping: MAE = 0.00553, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 77: MAE = 0.00539
# Check stopping: MAE = 0.00539, Cov Gradient Stable = True
# Iteration 78: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 79: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 80: MAE = 0.00536
# Check stopping: MAE = 0.00536, Cov Gradient Stable = True
# Iteration 81: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 82: MAE = 0.00536
# Check stopping: MAE = 0.00536, Cov Gradient Stable = True
# Iteration 83: MAE = 0.00535
# Check stopping: MAE = 0.00535, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 84: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# Iteration 85: MAE = 0.00532
# Check stopping: MAE = 0.00532, Cov Gradient Stable = True
# Iteration 86: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# Iteration 87: MAE = 0.00530
# Check stopping: MAE = 0.00530, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 88: MAE = 0.00529
# Check stopping: MAE = 0.00529, Cov Gradient Stable = True
# Iteration 89: MAE = 0.00528
# Check stopping: MAE = 0.00528, Cov Gradient Stable = True
# Iteration 90: MAE = 0.00524
# Check stopping: MAE = 0.00524, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 91: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 92: MAE = 0.00522
# Check stopping: MAE = 0.00522, Cov Gradient Stable = True
# Iteration 93: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 94: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 95: MAE = 0.00520
# Check stopping: MAE = 0.00520, Cov Gradient Stable = True
# Iteration 96: MAE = 0.00516
# Check stopping: MAE = 0.00516, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 97: MAE = 0.00515
# Check stopping: MAE = 0.00515, Cov Gradient Stable = True
# Iteration 98: MAE = 0.00514
# Check stopping: MAE = 0.00514, Cov Gradient Stable = True
# Iteration 99: MAE = 0.00514
# Check stopping: MAE = 0.00514, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 100: MAE = 0.00513
# Check stopping: MAE = 0.00513, Cov Gradient Stable = True
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10275_Ag-Au-Pd-Pt-Rh_RT
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# Iteration 1: MAE = 0.01629
# Iteration 2: MAE = 0.01396
# Iteration 3: MAE = 0.01442
# Iteration 4: MAE = 0.01448
# Iteration 5: MAE = 0.01428
# Iteration 6: MAE = 0.01188
# Iteration 7: MAE = 0.00973
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 8: MAE = 0.00966
# Iteration 9: MAE = 0.00787
# Iteration 10: MAE = 0.00795
# Iteration 11: MAE = 0.00807
# Iteration 12: MAE = 0.00776
# Iteration 13: MAE = 0.00761
# Iteration 14: MAE = 0.00747
# Iteration 15: MAE = 0.00734
# Iteration 16: MAE = 0.00733
# Iteration 17: MAE = 0.00744
# Iteration 18: MAE = 0.00742
# Iteration 19: MAE = 0.00744
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 20: MAE = 0.00708
# Iteration 21: MAE = 0.00666
# Iteration 22: MAE = 0.00657
# Iteration 23: MAE = 0.00656
# Iteration 24: MAE = 0.00731
# Iteration 25: MAE = 0.00725
# Iteration 26: MAE = 0.00729
# Iteration 27: MAE = 0.00721
# Iteration 28: MAE = 0.00720
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 29: MAE = 0.00721
# Iteration 30: MAE = 0.00728
# Check stopping: MAE = 0.00728, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00727
# Check stopping: MAE = 0.00727, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00719
# Check stopping: MAE = 0.00719, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00721
# Check stopping: MAE = 0.00721, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00723
# Check stopping: MAE = 0.00723, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00721
# Check stopping: MAE = 0.00721, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 36: MAE = 0.00698
# Check stopping: MAE = 0.00698, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00694
# Check stopping: MAE = 0.00694, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00692
# Check stopping: MAE = 0.00692, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00691
# Check stopping: MAE = 0.00691, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00691
# Check stopping: MAE = 0.00691, Cov Gradient Stable = True
# Iteration 42: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = True
# Iteration 43: MAE = 0.00699
# Check stopping: MAE = 0.00699, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 44: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = True
# Iteration 45: MAE = 0.00701
# Check stopping: MAE = 0.00701, Cov Gradient Stable = True
# Iteration 46: MAE = 0.00692
# Check stopping: MAE = 0.00692, Cov Gradient Stable = True
# Iteration 47: MAE = 0.00692
# Check stopping: MAE = 0.00692, Cov Gradient Stable = True
# Iteration 48: MAE = 0.00679
# Check stopping: MAE = 0.00679, Cov Gradient Stable = True
# Iteration 49: MAE = 0.00674
# Check stopping: MAE = 0.00674, Cov Gradient Stable = True
# Iteration 50: MAE = 0.00679
# Check stopping: MAE = 0.00679, Cov Gradient Stable = True
# Iteration 51: MAE = 0.00670
# Check stopping: MAE = 0.00670, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 52: MAE = 0.00671
# Check stopping: MAE = 0.00671, Cov Gradient Stable = True
# Iteration 53: MAE = 0.00673
# Check stopping: MAE = 0.00673, Cov Gradient Stable = True
# Iteration 54: MAE = 0.00669
# Check stopping: MAE = 0.00669, Cov Gradient Stable = True
# Iteration 55: MAE = 0.00666
# Check stopping: MAE = 0.00666, Cov Gradient Stable = True
# Iteration 56: MAE = 0.00632
# Check stopping: MAE = 0.00632, Cov Gradient Stable = True
# Iteration 57: MAE = 0.00628
# Check stopping: MAE = 0.00628, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 58: MAE = 0.00620
# Check stopping: MAE = 0.00620, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00619
# Check stopping: MAE = 0.00619, Cov Gradient Stable = True
# Iteration 60: MAE = 0.00614
# Check stopping: MAE = 0.00614, Cov Gradient Stable = True
# Iteration 61: MAE = 0.00616
# Check stopping: MAE = 0.00616, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 62: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = True
# Iteration 63: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = True
# Iteration 64: MAE = 0.00596
# Check stopping: MAE = 0.00596, Cov Gradient Stable = True
# Iteration 65: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 66: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = True
# Iteration 67: MAE = 0.00580
# Check stopping: MAE = 0.00580, Cov Gradient Stable = True
# Iteration 68: MAE = 0.00571
# Check stopping: MAE = 0.00571, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 69: MAE = 0.00570
# Check stopping: MAE = 0.00570, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00569
# Check stopping: MAE = 0.00569, Cov Gradient Stable = True
# Iteration 71: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = True
# Iteration 72: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 73: MAE = 0.00565
# Check stopping: MAE = 0.00565, Cov Gradient Stable = True
# Iteration 74: MAE = 0.00557
# Check stopping: MAE = 0.00557, Cov Gradient Stable = True
# Iteration 75: MAE = 0.00554
# Check stopping: MAE = 0.00554, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 76: MAE = 0.00553
# Check stopping: MAE = 0.00553, Cov Gradient Stable = True
# Iteration 77: MAE = 0.00539
# Check stopping: MAE = 0.00539, Cov Gradient Stable = True
# Iteration 78: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 79: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 80: MAE = 0.00536
# Check stopping: MAE = 0.00536, Cov Gradient Stable = True
# Iteration 81: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 82: MAE = 0.00536
# Check stopping: MAE = 0.00536, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 83: MAE = 0.00535
# Check stopping: MAE = 0.00535, Cov Gradient Stable = True
# Iteration 84: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# Iteration 85: MAE = 0.00532
# Check stopping: MAE = 0.00532, Cov Gradient Stable = True
# Iteration 86: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 87: MAE = 0.00530
# Check stopping: MAE = 0.00530, Cov Gradient Stable = True
# Iteration 88: MAE = 0.00529
# Check stopping: MAE = 0.00529, Cov Gradient Stable = True
# Iteration 89: MAE = 0.00528
# Check stopping: MAE = 0.00528, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 90: MAE = 0.00524
# Check stopping: MAE = 0.00524, Cov Gradient Stable = True
# Iteration 91: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 92: MAE = 0.00522
# Check stopping: MAE = 0.00522, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 93: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 94: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 95: MAE = 0.00520
# Check stopping: MAE = 0.00520, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 96: MAE = 0.00516
# Check stopping: MAE = 0.00516, Cov Gradient Stable = True
# Iteration 97: MAE = 0.00515
# Check stopping: MAE = 0.00515, Cov Gradient Stable = True
# Iteration 98: MAE = 0.00514
# Check stopping: MAE = 0.00514, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 99: MAE = 0.00514
# Check stopping: MAE = 0.00514, Cov Gradient Stable = True
# Iteration 100: MAE = 0.00513
# Check stopping: MAE = 0.00513, Cov Gradient Stable = True
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10275_Ag-Au-Pd-Pt-Rh_RT
#
# --- Processing: 10304_Au-Pd-Pt-Rh_RT ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 4), y = (9, 1), len(variables) = 4
# Iteration 1: MAE = 0.02011
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 2: MAE = 0.01844
# Iteration 3: MAE = 0.01421
# Iteration 4: MAE = 0.01452
# Iteration 5: MAE = 0.01378
# Iteration 6: MAE = 0.01162
# Iteration 7: MAE = 0.01080
# Iteration 8: MAE = 0.01025
# Iteration 9: MAE = 0.01013
# Iteration 10: MAE = 0.01001
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 11: MAE = 0.00957
# Iteration 12: MAE = 0.00954
# Iteration 13: MAE = 0.00938
# Iteration 14: MAE = 0.00910
# Iteration 15: MAE = 0.00917
# Iteration 16: MAE = 0.00894
# Iteration 17: MAE = 0.00878
# Iteration 18: MAE = 0.00736
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 19: MAE = 0.00696
# Iteration 20: MAE = 0.00679
# Iteration 21: MAE = 0.00681
# Iteration 22: MAE = 0.00685
# Iteration 23: MAE = 0.00677
# Iteration 24: MAE = 0.00672
# Iteration 25: MAE = 0.00671
# Iteration 26: MAE = 0.00670
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 27: MAE = 0.00672
# Iteration 28: MAE = 0.00661
# Iteration 29: MAE = 0.00654
# Iteration 30: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00585
# Check stopping: MAE = 0.00585, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00583
# Check stopping: MAE = 0.00583, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 33: MAE = 0.00583
# Check stopping: MAE = 0.00583, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00562
# Check stopping: MAE = 0.00562, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00560
# Check stopping: MAE = 0.00560, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00574
# Check stopping: MAE = 0.00574, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 40: MAE = 0.00558
# Check stopping: MAE = 0.00558, Cov Gradient Stable = True
# Iteration 41: MAE = 0.00559
# Check stopping: MAE = 0.00559, Cov Gradient Stable = True
# Iteration 42: MAE = 0.00558
# Check stopping: MAE = 0.00558, Cov Gradient Stable = True
# Iteration 43: MAE = 0.00557
# Check stopping: MAE = 0.00557, Cov Gradient Stable = True
# Iteration 44: MAE = 0.00556
# Check stopping: MAE = 0.00556, Cov Gradient Stable = True
# Iteration 45: MAE = 0.00553
# Check stopping: MAE = 0.00553, Cov Gradient Stable = True
# Iteration 46: MAE = 0.00553
# Check stopping: MAE = 0.00553, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 47: MAE = 0.00554
# Check stopping: MAE = 0.00554, Cov Gradient Stable = False
# Iteration 48: MAE = 0.00557
# Check stopping: MAE = 0.00557, Cov Gradient Stable = True
# Iteration 49: MAE = 0.00562
# Check stopping: MAE = 0.00562, Cov Gradient Stable = True
# Iteration 50: MAE = 0.00565
# Check stopping: MAE = 0.00565, Cov Gradient Stable = True
# Iteration 51: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = True
# Iteration 52: MAE = 0.00542
# Check stopping: MAE = 0.00542, Cov Gradient Stable = True
# Iteration 53: MAE = 0.00546
# Check stopping: MAE = 0.00546, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 54: MAE = 0.00546
# Check stopping: MAE = 0.00546, Cov Gradient Stable = True
# Iteration 55: MAE = 0.00543
# Check stopping: MAE = 0.00543, Cov Gradient Stable = False
# Iteration 56: MAE = 0.00543
# Check stopping: MAE = 0.00543, Cov Gradient Stable = True
# Iteration 57: MAE = 0.00545
# Check stopping: MAE = 0.00545, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 58: MAE = 0.00544
# Check stopping: MAE = 0.00544, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00543
# Check stopping: MAE = 0.00543, Cov Gradient Stable = True
# Iteration 60: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 61: MAE = 0.00530
# Check stopping: MAE = 0.00530, Cov Gradient Stable = False
# Iteration 62: MAE = 0.00529
# Check stopping: MAE = 0.00529, Cov Gradient Stable = True
# Iteration 63: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# Iteration 64: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 65: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# Iteration 66: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# Iteration 67: MAE = 0.00528
# Check stopping: MAE = 0.00528, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 68: MAE = 0.00516
# Check stopping: MAE = 0.00516, Cov Gradient Stable = True
# Iteration 69: MAE = 0.00513
# Check stopping: MAE = 0.00513, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00512
# Check stopping: MAE = 0.00512, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 71: MAE = 0.00507
# Check stopping: MAE = 0.00507, Cov Gradient Stable = True
# Iteration 72: MAE = 0.00506
# Check stopping: MAE = 0.00506, Cov Gradient Stable = True
# Iteration 73: MAE = 0.00502
# Check stopping: MAE = 0.00502, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 74: MAE = 0.00502
# Check stopping: MAE = 0.00502, Cov Gradient Stable = True
# Iteration 75: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 76: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Iteration 77: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Iteration 78: MAE = 0.00496
# Check stopping: MAE = 0.00496, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 78 due to stopping condition.
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10304_Au-Pd-Pt-Rh_RT
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 4), y = (9, 1), len(variables) = 4
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 1: MAE = 0.02011
# Iteration 2: MAE = 0.01844
# Iteration 3: MAE = 0.01421
# Iteration 4: MAE = 0.01452
# Iteration 5: MAE = 0.01378
# Iteration 6: MAE = 0.01162
# Iteration 7: MAE = 0.01080
# Iteration 8: MAE = 0.01025
# Iteration 9: MAE = 0.01013
# Iteration 10: MAE = 0.01001
# Iteration 11: MAE = 0.00957
# Iteration 12: MAE = 0.00954
# Iteration 13: MAE = 0.00938
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 14: MAE = 0.00910
# Iteration 15: MAE = 0.00917
# Iteration 16: MAE = 0.00894
# Iteration 17: MAE = 0.00878
# Iteration 18: MAE = 0.00736
# Iteration 19: MAE = 0.00696
# Iteration 20: MAE = 0.00679
# Iteration 21: MAE = 0.00681
# Iteration 22: MAE = 0.00685
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 23: MAE = 0.00677
# Iteration 24: MAE = 0.00672
# Iteration 25: MAE = 0.00671
# Iteration 26: MAE = 0.00670
# Iteration 27: MAE = 0.00672
# Iteration 28: MAE = 0.00661
# Iteration 29: MAE = 0.00654
# Iteration 30: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 31: MAE = 0.00585
# Check stopping: MAE = 0.00585, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00583
# Check stopping: MAE = 0.00583, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00583
# Check stopping: MAE = 0.00583, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00562
# Check stopping: MAE = 0.00562, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00560
# Check stopping: MAE = 0.00560, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00574
# Check stopping: MAE = 0.00574, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 37: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00558
# Check stopping: MAE = 0.00558, Cov Gradient Stable = True
# Iteration 41: MAE = 0.00559
# Check stopping: MAE = 0.00559, Cov Gradient Stable = True
# Iteration 42: MAE = 0.00558
# Check stopping: MAE = 0.00558, Cov Gradient Stable = True
# Iteration 43: MAE = 0.00557
# Check stopping: MAE = 0.00557, Cov Gradient Stable = True
# Iteration 44: MAE = 0.00556
# Check stopping: MAE = 0.00556, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 45: MAE = 0.00553
# Check stopping: MAE = 0.00553, Cov Gradient Stable = True
# Iteration 46: MAE = 0.00553
# Check stopping: MAE = 0.00553, Cov Gradient Stable = True
# Iteration 47: MAE = 0.00554
# Check stopping: MAE = 0.00554, Cov Gradient Stable = False
# Iteration 48: MAE = 0.00557
# Check stopping: MAE = 0.00557, Cov Gradient Stable = True
# Iteration 49: MAE = 0.00562
# Check stopping: MAE = 0.00562, Cov Gradient Stable = True
# Iteration 50: MAE = 0.00565
# Check stopping: MAE = 0.00565, Cov Gradient Stable = True
# Iteration 51: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 52: MAE = 0.00542
# Check stopping: MAE = 0.00542, Cov Gradient Stable = True
# Iteration 53: MAE = 0.00546
# Check stopping: MAE = 0.00546, Cov Gradient Stable = False
# Iteration 54: MAE = 0.00546
# Check stopping: MAE = 0.00546, Cov Gradient Stable = True
# Iteration 55: MAE = 0.00543
# Check stopping: MAE = 0.00543, Cov Gradient Stable = False
# Iteration 56: MAE = 0.00543
# Check stopping: MAE = 0.00543, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 57: MAE = 0.00545
# Check stopping: MAE = 0.00545, Cov Gradient Stable = True
# Iteration 58: MAE = 0.00544
# Check stopping: MAE = 0.00544, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00543
# Check stopping: MAE = 0.00543, Cov Gradient Stable = True
# Iteration 60: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 61: MAE = 0.00530
# Check stopping: MAE = 0.00530, Cov Gradient Stable = False
# Iteration 62: MAE = 0.00529
# Check stopping: MAE = 0.00529, Cov Gradient Stable = True
# Iteration 63: MAE = 0.00533
# Check stopping: MAE = 0.00533, Cov Gradient Stable = True
# Iteration 64: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 65: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# Iteration 66: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# Iteration 67: MAE = 0.00528
# Check stopping: MAE = 0.00528, Cov Gradient Stable = True
# Iteration 68: MAE = 0.00516
# Check stopping: MAE = 0.00516, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 69: MAE = 0.00513
# Check stopping: MAE = 0.00513, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00512
# Check stopping: MAE = 0.00512, Cov Gradient Stable = True
# Iteration 71: MAE = 0.00507
# Check stopping: MAE = 0.00507, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 72: MAE = 0.00506
# Check stopping: MAE = 0.00506, Cov Gradient Stable = True
# Iteration 73: MAE = 0.00502
# Check stopping: MAE = 0.00502, Cov Gradient Stable = True
# Iteration 74: MAE = 0.00502
# Check stopping: MAE = 0.00502, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 75: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Iteration 76: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Iteration 77: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 78: MAE = 0.00496
# Check stopping: MAE = 0.00496, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 78 due to stopping condition.
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10304_Au-Pd-Pt-Rh_RT
#
# --- Processing: 10311_Au-Pd-Pt-Rh-Ru_RT ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Au' 'Pd' 'Pt' 'Rh' 'Ru' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# Iteration 1: MAE = 0.01054
# Iteration 2: MAE = 0.01048
# Iteration 3: MAE = 0.00943
# Iteration 4: MAE = 0.00941
# Iteration 5: MAE = 0.01006
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 6: MAE = 0.01013
# Iteration 7: MAE = 0.00862
# ...
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 48: MAE = 0.00673
# Check stopping: MAE = 0.00673, Cov Gradient Stable = False
# Iteration 49: MAE = 0.00667
# Check stopping: MAE = 0.00667, Cov Gradient Stable = False
# Iteration 50: MAE = 0.00658
# Check stopping: MAE = 0.00658, Cov Gradient Stable = False
# Iteration 51: MAE = 0.00620
# Check stopping: MAE = 0.00620, Cov Gradient Stable = False
# Iteration 52: MAE = 0.00601
# Check stopping: MAE = 0.00601, Cov Gradient Stable = False
# Iteration 53: MAE = 0.00595
# Check stopping: MAE = 0.00595, Cov Gradient Stable = False
# Iteration 54: MAE = 0.00592
# Check stopping: MAE = 0.00592, Cov Gradient Stable = False
# Iteration 55: MAE = 0.00592
# Check stopping: MAE = 0.00592, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 56: MAE = 0.00589
# Check stopping: MAE = 0.00589, Cov Gradient Stable = True
# Iteration 57: MAE = 0.00587
# Check stopping: MAE = 0.00587, Cov Gradient Stable = True
# Iteration 58: MAE = 0.00583
# Check stopping: MAE = 0.00583, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00581
# Check stopping: MAE = 0.00581, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 60: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# Iteration 61: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# Iteration 62: MAE = 0.00574
# Check stopping: MAE = 0.00574, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 63: MAE = 0.00572
# Check stopping: MAE = 0.00572, Cov Gradient Stable = False
# Iteration 64: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = True
# Iteration 65: MAE = 0.00563
# Check stopping: MAE = 0.00563, Cov Gradient Stable = True
# Iteration 66: MAE = 0.00556
# Check stopping: MAE = 0.00556, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 67: MAE = 0.00550
# Check stopping: MAE = 0.00550, Cov Gradient Stable = True
# Iteration 68: MAE = 0.00549
# Check stopping: MAE = 0.00549, Cov Gradient Stable = True
# Iteration 69: MAE = 0.00548
# Check stopping: MAE = 0.00548, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00548
# Check stopping: MAE = 0.00548, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 71: MAE = 0.00547
# Check stopping: MAE = 0.00547, Cov Gradient Stable = True
# Iteration 72: MAE = 0.00547
# Check stopping: MAE = 0.00547, Cov Gradient Stable = True
# Iteration 73: MAE = 0.00541
# Check stopping: MAE = 0.00541, Cov Gradient Stable = True
# Iteration 74: MAE = 0.00539
# Check stopping: MAE = 0.00539, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 75: MAE = 0.00529
# Check stopping: MAE = 0.00529, Cov Gradient Stable = True
# Iteration 76: MAE = 0.00513
# Check stopping: MAE = 0.00513, Cov Gradient Stable = True
# Iteration 77: MAE = 0.00509
# Check stopping: MAE = 0.00509, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 78: MAE = 0.00509
# Check stopping: MAE = 0.00509, Cov Gradient Stable = True
# Iteration 79: MAE = 0.00508
# Check stopping: MAE = 0.00508, Cov Gradient Stable = True
# Iteration 80: MAE = 0.00508
# Check stopping: MAE = 0.00508, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 81: MAE = 0.00506
# Check stopping: MAE = 0.00506, Cov Gradient Stable = True
# Iteration 82: MAE = 0.00506
# Check stopping: MAE = 0.00506, Cov Gradient Stable = True
# Iteration 83: MAE = 0.00502
# Check stopping: MAE = 0.00502, Cov Gradient Stable = True
# Iteration 84: MAE = 0.00478
# Check stopping: MAE = 0.00478, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 84 due to stopping condition.
# reconstraining parameters GP_regression
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10399_Au-Cu-Pd-Pt_RT
#
# --- Processing: 10374_Ir_Pd_Pt-Rh_Ru ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ru' 'Rh' 'Pd' 'Ir' 'Pt' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 1: MAE = 0.00891
# Iteration 2: MAE = 0.00892
# Iteration 3: MAE = 0.00793
# Iteration 4: MAE = 0.00778
# Iteration 5: MAE = 0.00677
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 6: MAE = 0.00670
# Iteration 7: MAE = 0.00661
# Iteration 8: MAE = 0.00662
# Iteration 9: MAE = 0.00663
# Iteration 10: MAE = 0.00656
# Iteration 11: MAE = 0.00658
# Iteration 12: MAE = 0.00662
# Iteration 13: MAE = 0.00661
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 14: MAE = 0.00658
# Iteration 15: MAE = 0.00657
# Iteration 16: MAE = 0.00658
# Iteration 17: MAE = 0.00654
# Iteration 18: MAE = 0.00800
# Iteration 19: MAE = 0.00785
# Iteration 20: MAE = 0.00777
# Iteration 21: MAE = 0.00774
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 22: MAE = 0.00780
# Iteration 23: MAE = 0.00785
# Iteration 24: MAE = 0.00779
# Iteration 25: MAE = 0.00638
# Iteration 26: MAE = 0.00636
# Iteration 27: MAE = 0.00635
# Iteration 28: MAE = 0.00635
# Iteration 29: MAE = 0.00628
# Iteration 30: MAE = 0.00617
# Check stopping: MAE = 0.00617, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 31: MAE = 0.00614
# Check stopping: MAE = 0.00614, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00614
# Check stopping: MAE = 0.00614, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00612
# Check stopping: MAE = 0.00612, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00609
# Check stopping: MAE = 0.00609, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00605
# Check stopping: MAE = 0.00605, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00606
# Check stopping: MAE = 0.00606, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00608
# Check stopping: MAE = 0.00608, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00607
# Check stopping: MAE = 0.00607, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00607
# Check stopping: MAE = 0.00607, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 40: MAE = 0.00347
# Check stopping: MAE = 0.00347, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00391
# Check stopping: MAE = 0.00391, Cov Gradient Stable = False
# Iteration 42: MAE = 0.00383
# Check stopping: MAE = 0.00383, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 43: MAE = 0.00382
# Check stopping: MAE = 0.00382, Cov Gradient Stable = False
# Iteration 44: MAE = 0.00380
# Check stopping: MAE = 0.00380, Cov Gradient Stable = False
# Iteration 45: MAE = 0.00372
# Check stopping: MAE = 0.00372, Cov Gradient Stable = False
# Iteration 46: MAE = 0.00370
# Check stopping: MAE = 0.00370, Cov Gradient Stable = False
# Iteration 47: MAE = 0.00369
# Check stopping: MAE = 0.00369, Cov Gradient Stable = False
# Iteration 48: MAE = 0.00368
# Check stopping: MAE = 0.00368, Cov Gradient Stable = False
# Iteration 49: MAE = 0.00367
# Check stopping: MAE = 0.00367, Cov Gradient Stable = False
# Iteration 50: MAE = 0.00368
# Check stopping: MAE = 0.00368, Cov Gradient Stable = False
# Iteration 51: MAE = 0.00368
# Check stopping: MAE = 0.00368, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 51 due to stopping condition.
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10374_Ir_Pd_Pt-Rh_Ru
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ru' 'Rh' 'Pd' 'Ir' 'Pt' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 1: MAE = 0.00891
# Iteration 2: MAE = 0.00892
# Iteration 3: MAE = 0.00793
# Iteration 4: MAE = 0.00778
# Iteration 5: MAE = 0.00677
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 6: MAE = 0.00670
# Iteration 7: MAE = 0.00661
# Iteration 8: MAE = 0.00662
# Iteration 9: MAE = 0.00663
# Iteration 10: MAE = 0.00656
# Iteration 11: MAE = 0.00658
# Iteration 12: MAE = 0.00662
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 13: MAE = 0.00661
# Iteration 14: MAE = 0.00658
# Iteration 15: MAE = 0.00657
# Iteration 16: MAE = 0.00658
# Iteration 17: MAE = 0.00654
# Iteration 18: MAE = 0.00800
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 19: MAE = 0.00785
# Iteration 20: MAE = 0.00777
# Iteration 21: MAE = 0.00774
# Iteration 22: MAE = 0.00780
# Iteration 23: MAE = 0.00785
# Iteration 24: MAE = 0.00779
# Iteration 25: MAE = 0.00638
# Iteration 26: MAE = 0.00636
# Iteration 27: MAE = 0.00635
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 28: MAE = 0.00635
# Iteration 29: MAE = 0.00628
# Iteration 30: MAE = 0.00617
# Check stopping: MAE = 0.00617, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00614
# Check stopping: MAE = 0.00614, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00614
# Check stopping: MAE = 0.00614, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00612
# Check stopping: MAE = 0.00612, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00609
# Check stopping: MAE = 0.00609, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00605
# Check stopping: MAE = 0.00605, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 36: MAE = 0.00606
# Check stopping: MAE = 0.00606, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00608
# Check stopping: MAE = 0.00608, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00607
# Check stopping: MAE = 0.00607, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00607
# Check stopping: MAE = 0.00607, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 40: MAE = 0.00347
# Check stopping: MAE = 0.00347, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00391
# Check stopping: MAE = 0.00391, Cov Gradient Stable = False
# Iteration 42: MAE = 0.00383
# Check stopping: MAE = 0.00383, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 43: MAE = 0.00382
# Check stopping: MAE = 0.00382, Cov Gradient Stable = False
# Iteration 44: MAE = 0.00380
# Check stopping: MAE = 0.00380, Cov Gradient Stable = False
# Iteration 45: MAE = 0.00372
# Check stopping: MAE = 0.00372, Cov Gradient Stable = False
# Iteration 46: MAE = 0.00370
# Check stopping: MAE = 0.00370, Cov Gradient Stable = False
# Iteration 47: MAE = 0.00369
# Check stopping: MAE = 0.00369, Cov Gradient Stable = False
# Iteration 48: MAE = 0.00368
# Check stopping: MAE = 0.00368, Cov Gradient Stable = False
# Iteration 49: MAE = 0.00367
# Check stopping: MAE = 0.00367, Cov Gradient Stable = False
# Iteration 50: MAE = 0.00368
# Check stopping: MAE = 0.00368, Cov Gradient Stable = False
# Iteration 51: MAE = 0.00368
# Check stopping: MAE = 0.00368, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 51 due to stopping condition.
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10374_Ir_Pd_Pt-Rh_Ru
#
# Saved summary for GPBasic to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\summary_stopping_iterations_GPBasic.csv
#
# Saved summary for GPSawei to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\summary_stopping_iterations_GPSawei.csv

# %%
init_indices
# Out:
# [128, 5, 198, 178, 338, 247, 122, 188, 253]

# %%
import os
import pandas as pd
import numpy as np

# --- CONFIG ---
dataset_path = DATASET_10311_Au_Pd_Pt_Rh_Ru_RT
init_indices = init_indices
target_col = "Resistance"
excluded_cols = ["ID", "x", "y"]
max_iter = 100

# --- OUTPUT DIR ---
dataset_name = os.path.splitext(os.path.basename(dataset_path))[0]
output_dir = os.path.join(EVENLY_PATH_Uncertainty, dataset_name)
os.makedirs(output_dir, exist_ok=True)

# --- LOAD DATA ---
df = pd.read_csv(dataset_path)
df[target_col] = np.log(df[target_col])

features = [c for c in df.columns if c not in excluded_cols + [target_col]]
target = [target_col]

# --- RUN ACTIVE LEARNING LOOP ---
mae_collection, mean_collection, stopping_index, gradient_stable_index = loop(
    df=df,
    features=features,
    target=target,
    init=init_indices,
    imax=max_iter,
    gp_class=GPBasic
)

# --- SAVE MAE ---
mae_df = pd.DataFrame({"Iteration": range(len(mae_collection)), "MAE": mae_collection})
mae_df.to_csv(os.path.join(output_dir, "mae_history.csv"), index=False)

# --- SAVE MEAN COLLECTION (each iteration predictions) ---
mean_array = np.array([m.squeeze() for m in mean_collection])  # shape = (iterations, n_points)

# Transpose so rows = points, columns = iterations
mean_df = pd.DataFrame(mean_array.T)
mean_df.columns = [f"Iter_{i}" for i in range(mean_array.shape[0])]
mean_df.insert(0, "Index", range(mean_array.shape[1]))  # optional index column

# --- SAVE FINAL PREDICTIONS ---
final_pred = np.array(mean_collection[-1]).squeeze()  # from (342,1) → (342,)
final_true = np.exp(df[target_col].values).squeeze()

final_df = pd.DataFrame({
    "True_Resistance": final_true,
    "Predicted_Resistance": final_pred
})
final_df.to_csv(os.path.join(output_dir, "final_predictions.csv"), index=False)



# --- SAVE INFO ---
with open(os.path.join(output_dir, "info.txt"), "w") as f:
    f.write(f"Stopped at iteration: {stopping_index}\n")
    f.write(f"Gradient stable index: {gradient_stable_index}\n")
    f.write(f"Init indices: {init_indices}\n")

print(f"Results saved to: {output_dir}")
# Out:
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Au' 'Pd' 'Pt' 'Rh' 'Ru' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# Iteration 1: MAE = 0.01054
# Iteration 2: MAE = 0.01048
# Iteration 3: MAE = 0.00943
# Iteration 4: MAE = 0.00941
# Iteration 5: MAE = 0.01006
# Iteration 6: MAE = 0.01013
# Iteration 7: MAE = 0.00862
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 8: MAE = 0.00880
# Iteration 9: MAE = 0.00895
# Iteration 10: MAE = 0.00953
# Iteration 11: MAE = 0.00946
# Iteration 12: MAE = 0.00920
# Iteration 13: MAE = 0.00863
# Iteration 14: MAE = 0.00851
# Iteration 15: MAE = 0.00859
# Iteration 16: MAE = 0.00882
# Iteration 17: MAE = 0.00865
# Iteration 18: MAE = 0.00849
# Iteration 19: MAE = 0.00762
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 20: MAE = 0.00753
# Iteration 21: MAE = 0.00744
# Iteration 22: MAE = 0.00738
# Iteration 23: MAE = 0.00726
# Iteration 24: MAE = 0.00716
# Iteration 25: MAE = 0.00722
# Iteration 26: MAE = 0.00700
# Iteration 27: MAE = 0.00703
# Iteration 28: MAE = 0.00679
# Iteration 29: MAE = 0.00685
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 30: MAE = 0.00648
# Check stopping: MAE = 0.00648, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00647
# Check stopping: MAE = 0.00647, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00646
# Check stopping: MAE = 0.00646, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00646
# Check stopping: MAE = 0.00646, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00565
# Check stopping: MAE = 0.00565, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00546
# Check stopping: MAE = 0.00546, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00540
# Check stopping: MAE = 0.00540, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 39: MAE = 0.00539
# Check stopping: MAE = 0.00539, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00539
# Check stopping: MAE = 0.00539, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00516
# Check stopping: MAE = 0.00516, Cov Gradient Stable = False
# Iteration 42: MAE = 0.00458
# Check stopping: MAE = 0.00458, Cov Gradient Stable = False
# Iteration 43: MAE = 0.00457
# Check stopping: MAE = 0.00457, Cov Gradient Stable = False
# Iteration 44: MAE = 0.00457
# Check stopping: MAE = 0.00457, Cov Gradient Stable = False
# Iteration 45: MAE = 0.00457
# Check stopping: MAE = 0.00457, Cov Gradient Stable = False
# Iteration 46: MAE = 0.00450
# Check stopping: MAE = 0.00450, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 47: MAE = 0.00450
# Check stopping: MAE = 0.00450, Cov Gradient Stable = False
# Iteration 48: MAE = 0.00449
# Check stopping: MAE = 0.00449, Cov Gradient Stable = False
# Iteration 49: MAE = 0.00448
# Check stopping: MAE = 0.00448, Cov Gradient Stable = False
# Iteration 50: MAE = 0.00436
# Check stopping: MAE = 0.00436, Cov Gradient Stable = False
# Iteration 51: MAE = 0.00426
# Check stopping: MAE = 0.00426, Cov Gradient Stable = False
# Iteration 52: MAE = 0.00427
# Check stopping: MAE = 0.00427, Cov Gradient Stable = False
# Iteration 53: MAE = 0.00420
# Check stopping: MAE = 0.00420, Cov Gradient Stable = False
# Iteration 54: MAE = 0.00421
# Check stopping: MAE = 0.00421, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 55: MAE = 0.00415
# Check stopping: MAE = 0.00415, Cov Gradient Stable = False
# Iteration 56: MAE = 0.00389
# Check stopping: MAE = 0.00389, Cov Gradient Stable = False
# Iteration 57: MAE = 0.00384
# Check stopping: MAE = 0.00384, Cov Gradient Stable = False
# Iteration 58: MAE = 0.00380
# Check stopping: MAE = 0.00380, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 59: MAE = 0.00380
# Check stopping: MAE = 0.00380, Cov Gradient Stable = False
# Iteration 60: MAE = 0.00377
# Check stopping: MAE = 0.00377, Cov Gradient Stable = False
# Iteration 61: MAE = 0.00378
# Check stopping: MAE = 0.00378, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 62: MAE = 0.00376
# Check stopping: MAE = 0.00376, Cov Gradient Stable = False
# Iteration 63: MAE = 0.00375
# Check stopping: MAE = 0.00375, Cov Gradient Stable = False
# Iteration 64: MAE = 0.00359
# Check stopping: MAE = 0.00359, Cov Gradient Stable = False
# Iteration 65: MAE = 0.00358
# Check stopping: MAE = 0.00358, Cov Gradient Stable = False
# Iteration 66: MAE = 0.00357
# Check stopping: MAE = 0.00357, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 67: MAE = 0.00357
# Check stopping: MAE = 0.00357, Cov Gradient Stable = False
# Iteration 68: MAE = 0.00356
# Check stopping: MAE = 0.00356, Cov Gradient Stable = False
# Iteration 69: MAE = 0.00357
# Check stopping: MAE = 0.00357, Cov Gradient Stable = False
# Iteration 70: MAE = 0.00355
# Check stopping: MAE = 0.00355, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 71: MAE = 0.00353
# Check stopping: MAE = 0.00353, Cov Gradient Stable = False
# Iteration 72: MAE = 0.00348
# Check stopping: MAE = 0.00348, Cov Gradient Stable = False
# Iteration 73: MAE = 0.00352
# Check stopping: MAE = 0.00352, Cov Gradient Stable = False
# Iteration 74: MAE = 0.00352
# Check stopping: MAE = 0.00352, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 75: MAE = 0.00343
# Check stopping: MAE = 0.00343, Cov Gradient Stable = False
# Iteration 76: MAE = 0.00342
# Check stopping: MAE = 0.00342, Cov Gradient Stable = False
# Iteration 77: MAE = 0.00342
# Check stopping: MAE = 0.00342, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 78: MAE = 0.00342
# Check stopping: MAE = 0.00342, Cov Gradient Stable = False
# Iteration 79: MAE = 0.00342
# Check stopping: MAE = 0.00342, Cov Gradient Stable = False
# Iteration 80: MAE = 0.00340
# Check stopping: MAE = 0.00340, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 81: MAE = 0.00340
# Check stopping: MAE = 0.00340, Cov Gradient Stable = False
# Iteration 82: MAE = 0.00337
# Check stopping: MAE = 0.00337, Cov Gradient Stable = False
# Iteration 83: MAE = 0.00337
# Check stopping: MAE = 0.00337, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 84: MAE = 0.00337
# Check stopping: MAE = 0.00337, Cov Gradient Stable = False
# Iteration 85: MAE = 0.00336
# Check stopping: MAE = 0.00336, Cov Gradient Stable = False
# Iteration 86: MAE = 0.00329
# Check stopping: MAE = 0.00329, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 87: MAE = 0.00329
# Check stopping: MAE = 0.00329, Cov Gradient Stable = False
# Iteration 88: MAE = 0.00328
# Check stopping: MAE = 0.00328, Cov Gradient Stable = False
# Iteration 89: MAE = 0.00323
# Check stopping: MAE = 0.00323, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 90: MAE = 0.00323
# Check stopping: MAE = 0.00323, Cov Gradient Stable = False
# Iteration 91: MAE = 0.00322
# Check stopping: MAE = 0.00322, Cov Gradient Stable = False
# Iteration 92: MAE = 0.00321
# Check stopping: MAE = 0.00321, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 93: MAE = 0.00321
# Check stopping: MAE = 0.00321, Cov Gradient Stable = False
# Iteration 94: MAE = 0.00320
# Check stopping: MAE = 0.00320, Cov Gradient Stable = False
# Iteration 95: MAE = 0.00320
# Check stopping: MAE = 0.00320, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 96: MAE = 0.00320
# Check stopping: MAE = 0.00320, Cov Gradient Stable = False
# Iteration 97: MAE = 0.00320
# Check stopping: MAE = 0.00320, Cov Gradient Stable = False
# Iteration 98: MAE = 0.00318
# Check stopping: MAE = 0.00318, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# Iteration 99: MAE = 0.00314
# Check stopping: MAE = 0.00314, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 99 due to stopping condition.
# Results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10311_Au-Pd-Pt-Rh-Ru_RT
