# %%
import sys
sys.path.append("..")
from config import *
from scripts.measurement_devices import *
from scripts.gaussian_process_sawei import GPSawei
from scripts.run_active_learning import *
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
from scripts.plotting_MAE import *
from scripts.evenly_spaced_points import *

# %%
df = pd.read_csv(DATASET_10311_Au_Pd_Pt_Rh_Ru_RT)

init_indices = select_paper_style_points(df, x_col='x', y_col='y',  inner_step=3)

base_dir = MAE_PLOT
filename = "initialization_strategies_10311.pdf"
save_path = os.path.join(base_dir, filename)

plot_initialization_strategies_4(
    csv_path=DATASET_10311_Au_Pd_Pt_Rh_Ru_RT,
    all_init_strategies={
        "Fixed Grid": init_indices,
        
        "Min Comp": [
            199, 11, 23, 295, 340
        ],
        
        "Cent_sat_high": [
            144, 168, 80, 290, 270
        ],
        
        "Min Comp + Cent_sat_high": [
            144, 168, 80, 290, 270,
            199, 11, 23, 295, 340
        ]
    }, output_path=save_path
)
# Out:
#  c:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\notebook\..\scripts\plotting_MAE.py:400: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# Define all datasets
datasets = [
    DATASET_10272_Ag_Au_Pd_RT,
    DATASET_10275_Ag_Au_Pd_Pt_Rh_RT,
    DATASET_10304_Au_Pd_Pt_Rh_RT,
    DATASET_10311_Au_Pd_Pt_Rh_Ru_RT,
    DATASET_10403_Ag_Au_Cu_Pd_Pt_RT, 
    DATASET_10402_Ag_Au_Pd_Pt_RT,
    DATASET_10399_Au_Cu_Pd_Pt_RT,
    DATASET_10374_Ir_Pd_Pt_Rh_Ru
]

# Config
init_indices = init_indices  
target_col = "Resistance"
excluded_cols = ["ID", "x", "y"]
max_iter = 100

# Define GP variants and output paths
gp_class_dict = {
    "GPBasic": GPBasic,
    "GPSawei": GPSawei
}

output_base_path_dict = {
    "GPBasic": EVENLY_PATH_Uncertainty,
    "GPSawei": EVENLY_PATH_Sawei
}

# Store summaries
summary_results_dict = {}

# Run on all datasets
for dataset_path in datasets:
    run_active_learning_multiple_gp(
        dataset_path=dataset_path,
        init_indices=init_indices,
        target_col=target_col,
        excluded_cols=excluded_cols,
        max_iter=max_iter,
        output_base_path_dict=output_base_path_dict,
        gp_class_dict=gp_class_dict,
        summary_results_dict=summary_results_dict
    )

# Save summary tables for each GP variant
for gp_name, summary_data in summary_results_dict.items():
    summary_df = pd.DataFrame(summary_data)
    summary_path = os.path.join(output_base_path_dict[gp_name], f"summary_stopping_iterations_{gp_name}.csv")
    summary_df.to_csv(summary_path, index=False)
    print(f"\nSaved summary for {gp_name} to: {summary_path}")
# Out:
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# --- Processing: 10272_Ag-Au-Pd_RT ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 3), y = (9, 1), len(variables) = 3
# Iteration 1: MAE = 0.02076
# Iteration 2: MAE = 0.02069
# Iteration 3: MAE = 0.02074
# Iteration 4: MAE = 0.02026
# Iteration 5: MAE = 0.02061
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 6: MAE = 0.02072
# Iteration 7: MAE = 0.02074
# Iteration 8: MAE = 0.02091
# Iteration 9: MAE = 0.02075
# Iteration 10: MAE = 0.02123
# Iteration 11: MAE = 0.01974
# Iteration 12: MAE = 0.01997
# Iteration 13: MAE = 0.01104
# Iteration 14: MAE = 0.01127
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 15: MAE = 0.01138
# Iteration 16: MAE = 0.01055
# Iteration 17: MAE = 0.00870
# Iteration 18: MAE = 0.00760
# Iteration 19: MAE = 0.00760
# Iteration 20: MAE = 0.00742
# Iteration 21: MAE = 0.00739
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 22: MAE = 0.00738
# Iteration 23: MAE = 0.00739
# Iteration 24: MAE = 0.00756
# Iteration 25: MAE = 0.00685
# Iteration 26: MAE = 0.00690
# Iteration 27: MAE = 0.00679
# Iteration 28: MAE = 0.00654
# Iteration 29: MAE = 0.00619
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 30: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00593
# Check stopping: MAE = 0.00593, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00576
# Check stopping: MAE = 0.00576, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00584
# Check stopping: MAE = 0.00584, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00576
# Check stopping: MAE = 0.00576, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00524
# Check stopping: MAE = 0.00524, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00521
# Check stopping: MAE = 0.00521, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00513
# Check stopping: MAE = 0.00513, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00471
# Check stopping: MAE = 0.00471, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 39: MAE = 0.00469
# Check stopping: MAE = 0.00469, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00470
# Check stopping: MAE = 0.00470, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00464
# Check stopping: MAE = 0.00464, Cov Gradient Stable = False
# Iteration 42: MAE = 0.00438
# Check stopping: MAE = 0.00438, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 42 due to stopping condition.
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10272_Ag-Au-Pd_RT
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 3), y = (9, 1), len(variables) = 3
# Iteration 1: MAE = 0.02076
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 2: MAE = 0.02069
# Iteration 3: MAE = 0.02074
# Iteration 4: MAE = 0.02026
# Iteration 5: MAE = 0.02061
# Iteration 6: MAE = 0.02072
# Iteration 7: MAE = 0.02074
# Iteration 8: MAE = 0.02091
# Iteration 9: MAE = 0.02075
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 10: MAE = 0.02123
# Iteration 11: MAE = 0.01974
# Iteration 12: MAE = 0.01997
# Iteration 13: MAE = 0.01104
# Iteration 14: MAE = 0.01127
# Iteration 15: MAE = 0.01138
# Iteration 16: MAE = 0.01055
# Iteration 17: MAE = 0.00870
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 18: MAE = 0.00760
# Iteration 19: MAE = 0.00760
# Iteration 20: MAE = 0.00742
# Iteration 21: MAE = 0.00739
# Iteration 22: MAE = 0.00738
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 23: MAE = 0.00739
# Iteration 24: MAE = 0.00756
# Iteration 25: MAE = 0.00685
# Iteration 26: MAE = 0.00690
# Iteration 27: MAE = 0.00679
# Iteration 28: MAE = 0.00654
# Iteration 29: MAE = 0.00619
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 30: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00593
# Check stopping: MAE = 0.00593, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00576
# Check stopping: MAE = 0.00576, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00584
# Check stopping: MAE = 0.00584, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00576
# Check stopping: MAE = 0.00576, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00524
# Check stopping: MAE = 0.00524, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00521
# Check stopping: MAE = 0.00521, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00513
# Check stopping: MAE = 0.00513, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00471
# Check stopping: MAE = 0.00471, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 39: MAE = 0.00469
# Check stopping: MAE = 0.00469, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00470
# Check stopping: MAE = 0.00470, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00464
# Check stopping: MAE = 0.00464, Cov Gradient Stable = False
# Iteration 42: MAE = 0.00438
# Check stopping: MAE = 0.00438, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 42 due to stopping condition.
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10272_Ag-Au-Pd_RT
#
# --- Processing: 10275_Ag-Au-Pd-Pt-Rh_RT ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# Iteration 1: MAE = 0.01681
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 2: MAE = 0.01643
# Iteration 3: MAE = 0.01580
# Iteration 4: MAE = 0.01563
# Iteration 5: MAE = 0.01166
# Iteration 6: MAE = 0.00957
# Iteration 7: MAE = 0.00966
# Iteration 8: MAE = 0.00967
# Iteration 9: MAE = 0.00946
# Iteration 10: MAE = 0.00829
# Iteration 11: MAE = 0.00833
# Iteration 12: MAE = 0.00827
# Iteration 13: MAE = 0.00742
# Iteration 14: MAE = 0.00746
# Iteration 15: MAE = 0.00729
# Iteration 16: MAE = 0.00730
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 17: MAE = 0.00745
# Iteration 18: MAE = 0.00746
# Iteration 19: MAE = 0.00747
# Iteration 20: MAE = 0.00752
# Iteration 21: MAE = 0.00713
# Iteration 22: MAE = 0.00713
# Iteration 23: MAE = 0.00709
# Iteration 24: MAE = 0.00702
# Iteration 25: MAE = 0.00695
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 26: MAE = 0.00695
# Iteration 27: MAE = 0.00675
# Iteration 28: MAE = 0.00675
# Iteration 29: MAE = 0.00670
# Iteration 30: MAE = 0.00659
# Check stopping: MAE = 0.00659, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00658
# Check stopping: MAE = 0.00658, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00650
# Check stopping: MAE = 0.00650, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00650
# Check stopping: MAE = 0.00650, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00629
# Check stopping: MAE = 0.00629, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 35: MAE = 0.00623
# Check stopping: MAE = 0.00623, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00619
# Check stopping: MAE = 0.00619, Cov Gradient Stable = True
# Iteration 37: MAE = 0.00596
# Check stopping: MAE = 0.00596, Cov Gradient Stable = True
# Iteration 38: MAE = 0.00593
# Check stopping: MAE = 0.00593, Cov Gradient Stable = True
# Iteration 39: MAE = 0.00599
# Check stopping: MAE = 0.00599, Cov Gradient Stable = True
# Iteration 40: MAE = 0.00599
# Check stopping: MAE = 0.00599, Cov Gradient Stable = True
# Iteration 41: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = True
# Iteration 42: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 43: MAE = 0.00582
# Check stopping: MAE = 0.00582, Cov Gradient Stable = True
# Iteration 44: MAE = 0.00580
# Check stopping: MAE = 0.00580, Cov Gradient Stable = True
# Iteration 45: MAE = 0.00571
# Check stopping: MAE = 0.00571, Cov Gradient Stable = True
# Iteration 46: MAE = 0.00571
# Check stopping: MAE = 0.00571, Cov Gradient Stable = True
# Iteration 47: MAE = 0.00567
# Check stopping: MAE = 0.00567, Cov Gradient Stable = True
# Iteration 48: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = True
# Iteration 49: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = True
# Iteration 50: MAE = 0.00556
# Check stopping: MAE = 0.00556, Cov Gradient Stable = True
# Iteration 51: MAE = 0.00546
# Check stopping: MAE = 0.00546, Cov Gradient Stable = True
# Iteration 52: MAE = 0.00545
# Check stopping: MAE = 0.00545, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 53: MAE = 0.00541
# Check stopping: MAE = 0.00541, Cov Gradient Stable = True
# Iteration 54: MAE = 0.00542
# Check stopping: MAE = 0.00542, Cov Gradient Stable = True
# Iteration 55: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 56: MAE = 0.00535
# Check stopping: MAE = 0.00535, Cov Gradient Stable = True
# Iteration 57: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 58: MAE = 0.00539
# Check stopping: MAE = 0.00539, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# Iteration 60: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# Iteration 61: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 62: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 63: MAE = 0.00549
# Check stopping: MAE = 0.00549, Cov Gradient Stable = True
# Iteration 64: MAE = 0.00542
# Check stopping: MAE = 0.00542, Cov Gradient Stable = True
# Iteration 65: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# Iteration 66: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 67: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 68: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 69: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00516
# Check stopping: MAE = 0.00516, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 71: MAE = 0.00512
# Check stopping: MAE = 0.00512, Cov Gradient Stable = True
# Iteration 72: MAE = 0.00511
# Check stopping: MAE = 0.00511, Cov Gradient Stable = True
# Iteration 73: MAE = 0.00510
# Check stopping: MAE = 0.00510, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 74: MAE = 0.00507
# Check stopping: MAE = 0.00507, Cov Gradient Stable = True
# Iteration 75: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Iteration 76: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 76 due to stopping condition.
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10275_Ag-Au-Pd-Pt-Rh_RT
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ag' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 1: MAE = 0.01681
# Iteration 2: MAE = 0.01643
# Iteration 3: MAE = 0.01580
# Iteration 4: MAE = 0.01563
# Iteration 5: MAE = 0.01166
# Iteration 6: MAE = 0.00957
# Iteration 7: MAE = 0.00966
# Iteration 8: MAE = 0.00967
# Iteration 9: MAE = 0.00946
# Iteration 10: MAE = 0.00829
# Iteration 11: MAE = 0.00833
# Iteration 12: MAE = 0.00827
# Iteration 13: MAE = 0.00742
# Iteration 14: MAE = 0.00746
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 15: MAE = 0.00729
# Iteration 16: MAE = 0.00730
# Iteration 17: MAE = 0.00745
# Iteration 18: MAE = 0.00746
# Iteration 19: MAE = 0.00747
# Iteration 20: MAE = 0.00752
# Iteration 21: MAE = 0.00713
# Iteration 22: MAE = 0.00713
# Iteration 23: MAE = 0.00709
# Iteration 24: MAE = 0.00702
# Iteration 25: MAE = 0.00695
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 26: MAE = 0.00695
# Iteration 27: MAE = 0.00675
# Iteration 28: MAE = 0.00675
# Iteration 29: MAE = 0.00670
# Iteration 30: MAE = 0.00659
# Check stopping: MAE = 0.00659, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00658
# Check stopping: MAE = 0.00658, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00650
# Check stopping: MAE = 0.00650, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00650
# Check stopping: MAE = 0.00650, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00629
# Check stopping: MAE = 0.00629, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 35: MAE = 0.00623
# Check stopping: MAE = 0.00623, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00619
# Check stopping: MAE = 0.00619, Cov Gradient Stable = True
# Iteration 37: MAE = 0.00596
# Check stopping: MAE = 0.00596, Cov Gradient Stable = True
# Iteration 38: MAE = 0.00593
# Check stopping: MAE = 0.00593, Cov Gradient Stable = True
# Iteration 39: MAE = 0.00599
# Check stopping: MAE = 0.00599, Cov Gradient Stable = True
# Iteration 40: MAE = 0.00599
# Check stopping: MAE = 0.00599, Cov Gradient Stable = True
# Iteration 41: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = True
# Iteration 42: MAE = 0.00600
# Check stopping: MAE = 0.00600, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 43: MAE = 0.00582
# Check stopping: MAE = 0.00582, Cov Gradient Stable = True
# Iteration 44: MAE = 0.00580
# Check stopping: MAE = 0.00580, Cov Gradient Stable = True
# Iteration 45: MAE = 0.00571
# Check stopping: MAE = 0.00571, Cov Gradient Stable = True
# Iteration 46: MAE = 0.00571
# Check stopping: MAE = 0.00571, Cov Gradient Stable = True
# Iteration 47: MAE = 0.00567
# Check stopping: MAE = 0.00567, Cov Gradient Stable = True
# Iteration 48: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = True
# Iteration 49: MAE = 0.00564
# Check stopping: MAE = 0.00564, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 50: MAE = 0.00556
# Check stopping: MAE = 0.00556, Cov Gradient Stable = True
# Iteration 51: MAE = 0.00546
# Check stopping: MAE = 0.00546, Cov Gradient Stable = True
# Iteration 52: MAE = 0.00545
# Check stopping: MAE = 0.00545, Cov Gradient Stable = True
# Iteration 53: MAE = 0.00541
# Check stopping: MAE = 0.00541, Cov Gradient Stable = True
# Iteration 54: MAE = 0.00542
# Check stopping: MAE = 0.00542, Cov Gradient Stable = True
# Iteration 55: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 56: MAE = 0.00535
# Check stopping: MAE = 0.00535, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 57: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# Iteration 58: MAE = 0.00539
# Check stopping: MAE = 0.00539, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# Iteration 60: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 61: MAE = 0.00538
# Check stopping: MAE = 0.00538, Cov Gradient Stable = True
# Iteration 62: MAE = 0.00537
# Check stopping: MAE = 0.00537, Cov Gradient Stable = True
# Iteration 63: MAE = 0.00549
# Check stopping: MAE = 0.00549, Cov Gradient Stable = True
# Iteration 64: MAE = 0.00542
# Check stopping: MAE = 0.00542, Cov Gradient Stable = True
# Iteration 65: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 66: MAE = 0.00534
# Check stopping: MAE = 0.00534, Cov Gradient Stable = True
# Iteration 67: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 68: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# Iteration 69: MAE = 0.00523
# Check stopping: MAE = 0.00523, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 70: MAE = 0.00516
# Check stopping: MAE = 0.00516, Cov Gradient Stable = True
# Iteration 71: MAE = 0.00512
# Check stopping: MAE = 0.00512, Cov Gradient Stable = True
# Iteration 72: MAE = 0.00511
# Check stopping: MAE = 0.00511, Cov Gradient Stable = True
# Iteration 73: MAE = 0.00510
# Check stopping: MAE = 0.00510, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 74: MAE = 0.00507
# Check stopping: MAE = 0.00507, Cov Gradient Stable = True
# Iteration 75: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Iteration 76: MAE = 0.00500
# Check stopping: MAE = 0.00500, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 76 due to stopping condition.
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10275_Ag-Au-Pd-Pt-Rh_RT
#
# --- Processing: 10304_Au-Pd-Pt-Rh_RT ---
#
# >> Running with GP: GPBasic
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 4), y = (9, 1), len(variables) = 4
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 1: MAE = 0.03110
# Iteration 2: MAE = 0.02924
# Iteration 3: MAE = 0.02752
# Iteration 4: MAE = 0.02737
# Iteration 5: MAE = 0.02720
# Iteration 6: MAE = 0.02595
# Iteration 7: MAE = 0.02617
# Iteration 8: MAE = 0.02550
# Iteration 9: MAE = 0.02529
# Iteration 10: MAE = 0.02573
# Iteration 11: MAE = 0.02516
# Iteration 12: MAE = 0.02520
# Iteration 13: MAE = 0.02576
# Iteration 14: MAE = 0.02565
# Iteration 15: MAE = 0.02560
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 16: MAE = 0.02541
# Iteration 17: MAE = 0.02541
# Iteration 18: MAE = 0.02480
# Iteration 19: MAE = 0.02478
# Iteration 20: MAE = 0.02483
# Iteration 21: MAE = 0.02507
# Iteration 22: MAE = 0.02476
# Iteration 23: MAE = 0.02475
# Iteration 24: MAE = 0.02462
# Iteration 25: MAE = 0.02496
# Iteration 26: MAE = 0.02494
# Iteration 27: MAE = 0.02522
# Iteration 28: MAE = 0.02488
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 29: MAE = 0.02487
# Iteration 30: MAE = 0.02446
# Check stopping: MAE = 0.02446, Cov Gradient Stable = False
# Iteration 31: MAE = 0.02456
# Check stopping: MAE = 0.02456, Cov Gradient Stable = False
# Iteration 32: MAE = 0.02394
# Check stopping: MAE = 0.02394, Cov Gradient Stable = False
# Iteration 33: MAE = 0.02394
# Check stopping: MAE = 0.02394, Cov Gradient Stable = False
# Iteration 34: MAE = 0.02393
# Check stopping: MAE = 0.02393, Cov Gradient Stable = False
# Iteration 35: MAE = 0.02376
# Check stopping: MAE = 0.02376, Cov Gradient Stable = False
# Iteration 36: MAE = 0.02375
# Check stopping: MAE = 0.02375, Cov Gradient Stable = False
# Iteration 37: MAE = 0.02338
# Check stopping: MAE = 0.02338, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 38: MAE = 0.02331
# Check stopping: MAE = 0.02331, Cov Gradient Stable = False
# Iteration 39: MAE = 0.02323
# Check stopping: MAE = 0.02323, Cov Gradient Stable = False
# Iteration 40: MAE = 0.02321
# Check stopping: MAE = 0.02321, Cov Gradient Stable = False
# Iteration 41: MAE = 0.02311
# Check stopping: MAE = 0.02311, Cov Gradient Stable = False
# Iteration 42: MAE = 0.02309
# Check stopping: MAE = 0.02309, Cov Gradient Stable = False
# Iteration 43: MAE = 0.02325
# Check stopping: MAE = 0.02325, Cov Gradient Stable = False
# Iteration 44: MAE = 0.02350
# Check stopping: MAE = 0.02350, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 45: MAE = 0.02350
# Check stopping: MAE = 0.02350, Cov Gradient Stable = False
# Iteration 46: MAE = 0.02285
# Check stopping: MAE = 0.02285, Cov Gradient Stable = False
# Iteration 47: MAE = 0.02280
# Check stopping: MAE = 0.02280, Cov Gradient Stable = False
# Iteration 48: MAE = 0.02278
# Check stopping: MAE = 0.02278, Cov Gradient Stable = False
# Iteration 49: MAE = 0.02283
# Check stopping: MAE = 0.02283, Cov Gradient Stable = False
# Iteration 50: MAE = 0.02288
# Check stopping: MAE = 0.02288, Cov Gradient Stable = False
# Iteration 51: MAE = 0.02281
# Check stopping: MAE = 0.02281, Cov Gradient Stable = False
# Iteration 52: MAE = 0.02297
# Check stopping: MAE = 0.02297, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 53: MAE = 0.02324
# Check stopping: MAE = 0.02324, Cov Gradient Stable = False
# Iteration 54: MAE = 0.02308
# Check stopping: MAE = 0.02308, Cov Gradient Stable = False
# Iteration 55: MAE = 0.02306
# Check stopping: MAE = 0.02306, Cov Gradient Stable = False
# Iteration 56: MAE = 0.02302
# Check stopping: MAE = 0.02302, Cov Gradient Stable = False
# Iteration 57: MAE = 0.02259
# Check stopping: MAE = 0.02259, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 58: MAE = 0.02235
# Check stopping: MAE = 0.02235, Cov Gradient Stable = False
# Iteration 59: MAE = 0.02227
# Check stopping: MAE = 0.02227, Cov Gradient Stable = False
# Iteration 60: MAE = 0.02225
# Check stopping: MAE = 0.02225, Cov Gradient Stable = False
# Iteration 61: MAE = 0.02216
# Check stopping: MAE = 0.02216, Cov Gradient Stable = False
# Iteration 62: MAE = 0.02213
# Check stopping: MAE = 0.02213, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 63: MAE = 0.02206
# Check stopping: MAE = 0.02206, Cov Gradient Stable = False
# Iteration 64: MAE = 0.02215
# Check stopping: MAE = 0.02215, Cov Gradient Stable = False
# Iteration 65: MAE = 0.02201
# Check stopping: MAE = 0.02201, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 66: MAE = 0.02208
# Check stopping: MAE = 0.02208, Cov Gradient Stable = False
# Iteration 67: MAE = 0.02170
# Check stopping: MAE = 0.02170, Cov Gradient Stable = False
# Iteration 68: MAE = 0.02169
# Check stopping: MAE = 0.02169, Cov Gradient Stable = False
# Iteration 69: MAE = 0.02167
# Check stopping: MAE = 0.02167, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 70: MAE = 0.02154
# Check stopping: MAE = 0.02154, Cov Gradient Stable = False
# Iteration 71: MAE = 0.02139
# Check stopping: MAE = 0.02139, Cov Gradient Stable = False
# Iteration 72: MAE = 0.02117
# Check stopping: MAE = 0.02117, Cov Gradient Stable = False
# Iteration 73: MAE = 0.02112
# Check stopping: MAE = 0.02112, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 74: MAE = 0.02111
# Check stopping: MAE = 0.02111, Cov Gradient Stable = False
# Iteration 75: MAE = 0.02102
# Check stopping: MAE = 0.02102, Cov Gradient Stable = False
# Iteration 76: MAE = 0.02039
# Check stopping: MAE = 0.02039, Cov Gradient Stable = False
# Iteration 77: MAE = 0.02033
# Check stopping: MAE = 0.02033, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 78: MAE = 0.02027
# Check stopping: MAE = 0.02027, Cov Gradient Stable = False
# Iteration 79: MAE = 0.02009
# Check stopping: MAE = 0.02009, Cov Gradient Stable = False
# Iteration 80: MAE = 0.02007
# Check stopping: MAE = 0.02007, Cov Gradient Stable = False
# Iteration 81: MAE = 0.02007
# Check stopping: MAE = 0.02007, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 82: MAE = 0.01994
# Check stopping: MAE = 0.01994, Cov Gradient Stable = False
# Iteration 83: MAE = 0.01967
# Check stopping: MAE = 0.01967, Cov Gradient Stable = False
# Iteration 84: MAE = 0.01946
# Check stopping: MAE = 0.01946, Cov Gradient Stable = False
# Iteration 85: MAE = 0.01946
# Check stopping: MAE = 0.01946, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 86: MAE = 0.01941
# Check stopping: MAE = 0.01941, Cov Gradient Stable = False
# Iteration 87: MAE = 0.01919
# Check stopping: MAE = 0.01919, Cov Gradient Stable = False
# Iteration 88: MAE = 0.01919
# Check stopping: MAE = 0.01919, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 89: MAE = 0.01907
# Check stopping: MAE = 0.01907, Cov Gradient Stable = False
# Iteration 90: MAE = 0.01902
# Check stopping: MAE = 0.01902, Cov Gradient Stable = False
# Iteration 91: MAE = 0.01900
# Check stopping: MAE = 0.01900, Cov Gradient Stable = True
# Iteration 92: MAE = 0.01900
# Check stopping: MAE = 0.01900, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 93: MAE = 0.01899
# Check stopping: MAE = 0.01899, Cov Gradient Stable = True
# Iteration 94: MAE = 0.01899
# Check stopping: MAE = 0.01899, Cov Gradient Stable = False
# Iteration 95: MAE = 0.01895
# Check stopping: MAE = 0.01895, Cov Gradient Stable = True
# Iteration 96: MAE = 0.01894
# Check stopping: MAE = 0.01894, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 97: MAE = 0.01887
# Check stopping: MAE = 0.01887, Cov Gradient Stable = False
# Iteration 98: MAE = 0.01879
# Check stopping: MAE = 0.01879, Cov Gradient Stable = True
# Iteration 99: MAE = 0.01875
# Check stopping: MAE = 0.01875, Cov Gradient Stable = True
# Iteration 100: MAE = 0.01862
# Check stopping: MAE = 0.01862, Cov Gradient Stable = True
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10304_Au-Pd-Pt-Rh_RT
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Au' 'Pd' 'Pt' 'Rh' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 4), y = (9, 1), len(variables) = 4
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 1: MAE = 0.03110
# Iteration 2: MAE = 0.02924
# Iteration 3: MAE = 0.02752
# Iteration 4: MAE = 0.02737
# Iteration 5: MAE = 0.02720
# Iteration 6: MAE = 0.02595
# Iteration 7: MAE = 0.02617
# Iteration 8: MAE = 0.02550
# Iteration 9: MAE = 0.02529
# Iteration 10: MAE = 0.02573
# Iteration 11: MAE = 0.02516
# Iteration 12: MAE = 0.02520
# Iteration 13: MAE = 0.02576
# Iteration 14: MAE = 0.02565
# Iteration 15: MAE = 0.02560
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 16: MAE = 0.02541
# Iteration 17: MAE = 0.02541
# Iteration 18: MAE = 0.02480
# Iteration 19: MAE = 0.02478
# Iteration 20: MAE = 0.02483
# Iteration 21: MAE = 0.02507
# Iteration 22: MAE = 0.02476
# Iteration 23: MAE = 0.02475
# Iteration 24: MAE = 0.02462
# Iteration 25: MAE = 0.02496
# Iteration 26: MAE = 0.02494
# Iteration 27: MAE = 0.02522
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 28: MAE = 0.02488
# Iteration 29: MAE = 0.02487
# Iteration 30: MAE = 0.02446
# Check stopping: MAE = 0.02446, Cov Gradient Stable = False
# Iteration 31: MAE = 0.02456
# Check stopping: MAE = 0.02456, Cov Gradient Stable = False
# Iteration 32: MAE = 0.02394
# Check stopping: MAE = 0.02394, Cov Gradient Stable = False
# Iteration 33: MAE = 0.02394
# Check stopping: MAE = 0.02394, Cov Gradient Stable = False
# Iteration 34: MAE = 0.02393
# Check stopping: MAE = 0.02393, Cov Gradient Stable = False
# Iteration 35: MAE = 0.02376
# Check stopping: MAE = 0.02376, Cov Gradient Stable = False
# Iteration 36: MAE = 0.02375
# Check stopping: MAE = 0.02375, Cov Gradient Stable = False
# Iteration 37: MAE = 0.02338
# Check stopping: MAE = 0.02338, Cov Gradient Stable = False
# Iteration 38: MAE = 0.02331
# Check stopping: MAE = 0.02331, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 39: MAE = 0.02323
# Check stopping: MAE = 0.02323, Cov Gradient Stable = False
# Iteration 40: MAE = 0.02321
# Check stopping: MAE = 0.02321, Cov Gradient Stable = False
# Iteration 41: MAE = 0.02311
# Check stopping: MAE = 0.02311, Cov Gradient Stable = False
# Iteration 42: MAE = 0.02309
# Check stopping: MAE = 0.02309, Cov Gradient Stable = False
# Iteration 43: MAE = 0.02325
# Check stopping: MAE = 0.02325, Cov Gradient Stable = False
# Iteration 44: MAE = 0.02350
# Check stopping: MAE = 0.02350, Cov Gradient Stable = False
# Iteration 45: MAE = 0.02350
# Check stopping: MAE = 0.02350, Cov Gradient Stable = False
# Iteration 46: MAE = 0.02285
# Check stopping: MAE = 0.02285, Cov Gradient Stable = False
# Iteration 47: MAE = 0.02280
# Check stopping: MAE = 0.02280, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 48: MAE = 0.02278
# Check stopping: MAE = 0.02278, Cov Gradient Stable = False
# Iteration 49: MAE = 0.02283
# Check stopping: MAE = 0.02283, Cov Gradient Stable = False
# Iteration 50: MAE = 0.02288
# Check stopping: MAE = 0.02288, Cov Gradient Stable = False
# Iteration 51: MAE = 0.02281
# Check stopping: MAE = 0.02281, Cov Gradient Stable = False
# Iteration 52: MAE = 0.02297
# Check stopping: MAE = 0.02297, Cov Gradient Stable = False
# Iteration 53: MAE = 0.02324
# Check stopping: MAE = 0.02324, Cov Gradient Stable = False
# Iteration 54: MAE = 0.02308
# Check stopping: MAE = 0.02308, Cov Gradient Stable = False
# Iteration 55: MAE = 0.02306
# Check stopping: MAE = 0.02306, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 56: MAE = 0.02302
# Check stopping: MAE = 0.02302, Cov Gradient Stable = False
# Iteration 57: MAE = 0.02259
# Check stopping: MAE = 0.02259, Cov Gradient Stable = False
# Iteration 58: MAE = 0.02235
# Check stopping: MAE = 0.02235, Cov Gradient Stable = False
# Iteration 59: MAE = 0.02227
# Check stopping: MAE = 0.02227, Cov Gradient Stable = False
# Iteration 60: MAE = 0.02225
# Check stopping: MAE = 0.02225, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 61: MAE = 0.02216
# Check stopping: MAE = 0.02216, Cov Gradient Stable = False
# Iteration 62: MAE = 0.02213
# Check stopping: MAE = 0.02213, Cov Gradient Stable = False
# Iteration 63: MAE = 0.02206
# Check stopping: MAE = 0.02206, Cov Gradient Stable = False
# Iteration 64: MAE = 0.02215
# Check stopping: MAE = 0.02215, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 65: MAE = 0.02201
# Check stopping: MAE = 0.02201, Cov Gradient Stable = False
# Iteration 66: MAE = 0.02208
# Check stopping: MAE = 0.02208, Cov Gradient Stable = False
# Iteration 67: MAE = 0.02170
# Check stopping: MAE = 0.02170, Cov Gradient Stable = False
# Iteration 68: MAE = 0.02169
# Check stopping: MAE = 0.02169, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 69: MAE = 0.02167
# Check stopping: MAE = 0.02167, Cov Gradient Stable = False
# Iteration 70: MAE = 0.02154
# Check stopping: MAE = 0.02154, Cov Gradient Stable = False
# Iteration 71: MAE = 0.02139
# Check stopping: MAE = 0.02139, Cov Gradient Stable = False
# Iteration 72: MAE = 0.02117
# Check stopping: MAE = 0.02117, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 73: MAE = 0.02112
# Check stopping: MAE = 0.02112, Cov Gradient Stable = False
# Iteration 74: MAE = 0.02111
# Check stopping: MAE = 0.02111, Cov Gradient Stable = False
# Iteration 75: MAE = 0.02102
# Check stopping: MAE = 0.02102, Cov Gradient Stable = False
# Iteration 76: MAE = 0.02039
# Check stopping: MAE = 0.02039, Cov Gradient Stable = False
# Iteration 77: MAE = 0.02033
# Check stopping: MAE = 0.02033, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 78: MAE = 0.02027
# Check stopping: MAE = 0.02027, Cov Gradient Stable = False
# Iteration 79: MAE = 0.02009
# Check stopping: MAE = 0.02009, Cov Gradient Stable = False
# Iteration 80: MAE = 0.02007
# Check stopping: MAE = 0.02007, Cov Gradient Stable = False
# Iteration 81: MAE = 0.02007
# Check stopping: MAE = 0.02007, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 82: MAE = 0.01994
# Check stopping: MAE = 0.01994, Cov Gradient Stable = False
# Iteration 83: MAE = 0.01967
# Check stopping: MAE = 0.01967, Cov Gradient Stable = False
# Iteration 84: MAE = 0.01946
# Check stopping: MAE = 0.01946, Cov Gradient Stable = False
# Iteration 85: MAE = 0.01946
# Check stopping: MAE = 0.01946, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 86: MAE = 0.01941
# Check stopping: MAE = 0.01941, Cov Gradient Stable = False
# Iteration 87: MAE = 0.01919
# Check stopping: MAE = 0.01919, Cov Gradient Stable = False
# Iteration 88: MAE = 0.01919
# Check stopping: MAE = 0.01919, Cov Gradient Stable = False
# Iteration 89: MAE = 0.01907
# Check stopping: MAE = 0.01907, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 90: MAE = 0.01902
# Check stopping: MAE = 0.01902, Cov Gradient Stable = False
# Iteration 91: MAE = 0.01900
# Check stopping: MAE = 0.01900, Cov Gradient Stable = True
# Iteration 92: MAE = 0.01900
# Check stopping: MAE = 0.01900, Cov Gradient Stable = True
# Iteration 93: MAE = 0.01899
# Check stopping: MAE = 0.01899, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 94: MAE = 0.01899
# Check stopping: MAE = 0.01899, Cov Gradient Stable = False
# Iteration 95: MAE = 0.01895
# Check stopping: MAE = 0.01895, Cov Gradient Stable = True
# Iteration 96: MAE = 0.01894
# Check stopping: MAE = 0.01894, Cov Gradient Stable = False
# Iteration 97: MAE = 0.01887
# Check stopping: MAE = 0.01887, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 98: MAE = 0.01879
# Check stopping: MAE = 0.01879, Cov Gradient Stable = True
# Iteration 99: MAE = 0.01875
# Check stopping: MAE = 0.01875, Cov Gradient Stable = True
# Iteration 100: MAE = 0.01862
# Check stopping: MAE = 0.01862, Cov Gradient Stable = True
# ...
# Iteration 68: MAE = 0.00660
# Check stopping: MAE = 0.00660, Cov Gradient Stable = True
# Iteration 69: MAE = 0.00641
# Check stopping: MAE = 0.00641, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00641
# Check stopping: MAE = 0.00641, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 71: MAE = 0.00638
# Check stopping: MAE = 0.00638, Cov Gradient Stable = False
# Iteration 72: MAE = 0.00636
# Check stopping: MAE = 0.00636, Cov Gradient Stable = False
# Iteration 73: MAE = 0.00635
# Check stopping: MAE = 0.00635, Cov Gradient Stable = False
# Iteration 74: MAE = 0.00634
# Check stopping: MAE = 0.00634, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 75: MAE = 0.00636
# Check stopping: MAE = 0.00636, Cov Gradient Stable = False
# Iteration 76: MAE = 0.00631
# Check stopping: MAE = 0.00631, Cov Gradient Stable = False
# Iteration 77: MAE = 0.00631
# Check stopping: MAE = 0.00631, Cov Gradient Stable = False
# Iteration 78: MAE = 0.00613
# Check stopping: MAE = 0.00613, Cov Gradient Stable = False
# Iteration 79: MAE = 0.00613
# Check stopping: MAE = 0.00613, Cov Gradient Stable = False
# Iteration 80: MAE = 0.00612
# Check stopping: MAE = 0.00612, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 81: MAE = 0.00610
# Check stopping: MAE = 0.00610, Cov Gradient Stable = False
# Iteration 82: MAE = 0.00608
# Check stopping: MAE = 0.00608, Cov Gradient Stable = False
# Iteration 83: MAE = 0.00601
# Check stopping: MAE = 0.00601, Cov Gradient Stable = False
# Iteration 84: MAE = 0.00597
# Check stopping: MAE = 0.00597, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 85: MAE = 0.00597
# Check stopping: MAE = 0.00597, Cov Gradient Stable = False
# Iteration 86: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 87: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 88: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 89: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 90: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = False
# Iteration 91: MAE = 0.00588
# Check stopping: MAE = 0.00588, Cov Gradient Stable = False
# Iteration 92: MAE = 0.00588
# Check stopping: MAE = 0.00588, Cov Gradient Stable = False
# Iteration 93: MAE = 0.00586
# Check stopping: MAE = 0.00586, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 94: MAE = 0.00585
# Check stopping: MAE = 0.00585, Cov Gradient Stable = False
# Iteration 95: MAE = 0.00586
# Check stopping: MAE = 0.00586, Cov Gradient Stable = False
# Iteration 96: MAE = 0.00579
# Check stopping: MAE = 0.00579, Cov Gradient Stable = True
# Iteration 97: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# Iteration 98: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 99: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# Iteration 100: MAE = 0.00574
# Check stopping: MAE = 0.00574, Cov Gradient Stable = True
# GPBasic results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10374_Ir_Pd_Pt-Rh_Ru
#
# >> Running with GP: GPSawei
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Ru' 'Rh' 'Pd' 'Ir' 'Pt' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# Iteration 1: MAE = 0.00751
# Iteration 2: MAE = 0.00726
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 3: MAE = 0.00723
# Iteration 4: MAE = 0.00738
# Iteration 5: MAE = 0.00765
# Iteration 6: MAE = 0.00765
# Iteration 7: MAE = 0.00758
# Iteration 8: MAE = 0.00760
# Iteration 9: MAE = 0.00752
# Iteration 10: MAE = 0.00744
# Iteration 11: MAE = 0.00912
# Iteration 12: MAE = 0.00902
# Iteration 13: MAE = 0.00901
# Iteration 14: MAE = 0.00899
# Iteration 15: MAE = 0.00901
# Iteration 16: MAE = 0.00900
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 17: MAE = 0.00899
# Iteration 18: MAE = 0.00897
# Iteration 19: MAE = 0.00895
# Iteration 20: MAE = 0.00898
# Iteration 21: MAE = 0.00893
# Iteration 22: MAE = 0.00893
# Iteration 23: MAE = 0.00893
# Iteration 24: MAE = 0.00773
# Iteration 25: MAE = 0.00764
# Iteration 26: MAE = 0.00759
# Iteration 27: MAE = 0.00722
# Iteration 28: MAE = 0.00727
# Iteration 29: MAE = 0.00724
# Iteration 30: MAE = 0.00724
# Check stopping: MAE = 0.00724, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 31: MAE = 0.00725
# Check stopping: MAE = 0.00725, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00724
# Check stopping: MAE = 0.00724, Cov Gradient Stable = False
# Iteration 33: MAE = 0.00722
# Check stopping: MAE = 0.00722, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00726
# Check stopping: MAE = 0.00726, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00721
# Check stopping: MAE = 0.00721, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00721
# Check stopping: MAE = 0.00721, Cov Gradient Stable = False
# Iteration 37: MAE = 0.00723
# Check stopping: MAE = 0.00723, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00722
# Check stopping: MAE = 0.00722, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00721
# Check stopping: MAE = 0.00721, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00716
# Check stopping: MAE = 0.00716, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00714
# Check stopping: MAE = 0.00714, Cov Gradient Stable = False
# Iteration 42: MAE = 0.00715
# Check stopping: MAE = 0.00715, Cov Gradient Stable = False
# Iteration 43: MAE = 0.00715
# Check stopping: MAE = 0.00715, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 44: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = False
# Iteration 45: MAE = 0.00700
# Check stopping: MAE = 0.00700, Cov Gradient Stable = False
# Iteration 46: MAE = 0.00699
# Check stopping: MAE = 0.00699, Cov Gradient Stable = True
# Iteration 47: MAE = 0.00672
# Check stopping: MAE = 0.00672, Cov Gradient Stable = False
# Iteration 48: MAE = 0.00669
# Check stopping: MAE = 0.00669, Cov Gradient Stable = True
# Iteration 49: MAE = 0.00669
# Check stopping: MAE = 0.00669, Cov Gradient Stable = True
# Iteration 50: MAE = 0.00668
# Check stopping: MAE = 0.00668, Cov Gradient Stable = True
# Iteration 51: MAE = 0.00664
# Check stopping: MAE = 0.00664, Cov Gradient Stable = True
# Iteration 52: MAE = 0.00665
# Check stopping: MAE = 0.00665, Cov Gradient Stable = True
# Iteration 53: MAE = 0.00670
# Check stopping: MAE = 0.00670, Cov Gradient Stable = False
# Iteration 54: MAE = 0.00669
# Check stopping: MAE = 0.00669, Cov Gradient Stable = False
# Iteration 55: MAE = 0.00668
# Check stopping: MAE = 0.00668, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 56: MAE = 0.00668
# Check stopping: MAE = 0.00668, Cov Gradient Stable = True
# Iteration 57: MAE = 0.00670
# Check stopping: MAE = 0.00670, Cov Gradient Stable = True
# Iteration 58: MAE = 0.00670
# Check stopping: MAE = 0.00670, Cov Gradient Stable = True
# Iteration 59: MAE = 0.00669
# Check stopping: MAE = 0.00669, Cov Gradient Stable = True
# Iteration 60: MAE = 0.00669
# Check stopping: MAE = 0.00669, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 61: MAE = 0.00671
# Check stopping: MAE = 0.00671, Cov Gradient Stable = True
# Iteration 62: MAE = 0.00666
# Check stopping: MAE = 0.00666, Cov Gradient Stable = False
# Iteration 63: MAE = 0.00666
# Check stopping: MAE = 0.00666, Cov Gradient Stable = True
# Iteration 64: MAE = 0.00665
# Check stopping: MAE = 0.00665, Cov Gradient Stable = True
# Iteration 65: MAE = 0.00662
# Check stopping: MAE = 0.00662, Cov Gradient Stable = True
# Iteration 66: MAE = 0.00660
# Check stopping: MAE = 0.00660, Cov Gradient Stable = True
# Iteration 67: MAE = 0.00660
# Check stopping: MAE = 0.00660, Cov Gradient Stable = True
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 68: MAE = 0.00660
# Check stopping: MAE = 0.00660, Cov Gradient Stable = True
# Iteration 69: MAE = 0.00641
# Check stopping: MAE = 0.00641, Cov Gradient Stable = True
# Iteration 70: MAE = 0.00641
# Check stopping: MAE = 0.00641, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 71: MAE = 0.00638
# Check stopping: MAE = 0.00638, Cov Gradient Stable = False
# Iteration 72: MAE = 0.00636
# Check stopping: MAE = 0.00636, Cov Gradient Stable = False
# Iteration 73: MAE = 0.00635
# Check stopping: MAE = 0.00635, Cov Gradient Stable = False
# Iteration 74: MAE = 0.00634
# Check stopping: MAE = 0.00634, Cov Gradient Stable = False
# Iteration 75: MAE = 0.00636
# Check stopping: MAE = 0.00636, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 76: MAE = 0.00631
# Check stopping: MAE = 0.00631, Cov Gradient Stable = False
# Iteration 77: MAE = 0.00631
# Check stopping: MAE = 0.00631, Cov Gradient Stable = False
# Iteration 78: MAE = 0.00613
# Check stopping: MAE = 0.00613, Cov Gradient Stable = False
# Iteration 79: MAE = 0.00613
# Check stopping: MAE = 0.00613, Cov Gradient Stable = False
# Iteration 80: MAE = 0.00612
# Check stopping: MAE = 0.00612, Cov Gradient Stable = False
# Iteration 81: MAE = 0.00610
# Check stopping: MAE = 0.00610, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 82: MAE = 0.00608
# Check stopping: MAE = 0.00608, Cov Gradient Stable = False
# Iteration 83: MAE = 0.00601
# Check stopping: MAE = 0.00601, Cov Gradient Stable = False
# Iteration 84: MAE = 0.00597
# Check stopping: MAE = 0.00597, Cov Gradient Stable = False
# Iteration 85: MAE = 0.00597
# Check stopping: MAE = 0.00597, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 86: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 87: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 88: MAE = 0.00598
# Check stopping: MAE = 0.00598, Cov Gradient Stable = False
# Iteration 89: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 90: MAE = 0.00590
# Check stopping: MAE = 0.00590, Cov Gradient Stable = False
# Iteration 91: MAE = 0.00588
# Check stopping: MAE = 0.00588, Cov Gradient Stable = False
# Iteration 92: MAE = 0.00588
# Check stopping: MAE = 0.00588, Cov Gradient Stable = False
# Iteration 93: MAE = 0.00586
# Check stopping: MAE = 0.00586, Cov Gradient Stable = False
# Iteration 94: MAE = 0.00585
# Check stopping: MAE = 0.00585, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 95: MAE = 0.00586
# Check stopping: MAE = 0.00586, Cov Gradient Stable = False
# Iteration 96: MAE = 0.00579
# Check stopping: MAE = 0.00579, Cov Gradient Stable = True
# Iteration 97: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# Iteration 98: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# Iteration 99: MAE = 0.00575
# Check stopping: MAE = 0.00575, Cov Gradient Stable = True
# Iteration 100: MAE = 0.00574
# Check stopping: MAE = 0.00574, Cov Gradient Stable = True
# GPSawei results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\10374_Ir_Pd_Pt-Rh_Ru
#
# Saved summary for GPBasic to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\summary_stopping_iterations_GPBasic.csv
#
# Saved summary for GPSawei to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Sawei\summary_stopping_iterations_GPSawei.csv

# %%
init_indices
# Out:
# [5, 101, 107, 157, 167, 177, 227, 233, 338]

# %%
import os
import pandas as pd
import numpy as np

# --- CONFIG ---
dataset_path = DATASET_10311_Au_Pd_Pt_Rh_Ru_RT
init_indices = init_indices
target_col = "Resistance"
excluded_cols = ["ID", "x", "y"]
max_iter = 100

# --- OUTPUT DIR ---
dataset_name = os.path.splitext(os.path.basename(dataset_path))[0]
output_dir = os.path.join(EVENLY_PATH_Uncertainty, dataset_name)
os.makedirs(output_dir, exist_ok=True)

# --- LOAD DATA ---
df = pd.read_csv(dataset_path)
df[target_col] = np.log(df[target_col])

features = [c for c in df.columns if c not in excluded_cols + [target_col]]
target = [target_col]

# --- RUN ACTIVE LEARNING LOOP ---
mae_collection, mean_collection, stopping_index, gradient_stable_index = loop(
    df=df,
    features=features,
    target=target,
    init=init_indices,
    imax=max_iter,
    gp_class=GPBasic
)

# --- SAVE MAE ---
mae_df = pd.DataFrame({"Iteration": range(len(mae_collection)), "MAE": mae_collection})
mae_df.to_csv(os.path.join(output_dir, "mae_history.csv"), index=False)

# --- SAVE MEAN COLLECTION (each iteration predictions) ---
mean_array = np.array([m.squeeze() for m in mean_collection])  # shape = (iterations, n_points)

# Transpose so rows = points, columns = iterations
mean_df = pd.DataFrame(mean_array.T)
mean_df.columns = [f"Iter_{i}" for i in range(mean_array.shape[0])]
mean_df.insert(0, "Index", range(mean_array.shape[1]))  # optional index column

# --- SAVE FINAL PREDICTIONS ---
final_pred = np.array(mean_collection[-1]).squeeze()  # from (342,1) → (342,)
final_true = np.exp(df[target_col].values).squeeze()

final_df = pd.DataFrame({
    "True_Resistance": final_true,
    "Predicted_Resistance": final_pred
})
final_df.to_csv(os.path.join(output_dir, "final_predictions.csv"), index=False)



# --- SAVE INFO ---
with open(os.path.join(output_dir, "info.txt"), "w") as f:
    f.write(f"Stopped at iteration: {stopping_index}\n")
    f.write(f"Gradient stable index: {gradient_stable_index}\n")
    f.write(f"Init indices: {init_indices}\n")

print(f"Results saved to: {output_dir}")
# Out:
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Headers of DataFrame:
#  ['ID' 'x' 'y' 'Au' 'Pd' 'Pt' 'Rh' 'Ru' 'Resistance']
# Gaussian Process initialization:
#  X = (9, 5), y = (9, 1), len(variables) = 5
# Iteration 1: MAE = 0.01161
# Iteration 2: MAE = 0.00931
# Iteration 3: MAE = 0.00798
# Iteration 4: MAE = 0.00784
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 5: MAE = 0.00946
# Iteration 6: MAE = 0.00938
# Iteration 7: MAE = 0.00943
# Iteration 8: MAE = 0.00906
# Iteration 9: MAE = 0.00918
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 10: MAE = 0.00889
# Iteration 11: MAE = 0.00870
# Iteration 12: MAE = 0.00898
# Iteration 13: MAE = 0.00945
# Iteration 14: MAE = 0.00960
# Iteration 15: MAE = 0.00950
# Iteration 16: MAE = 0.00951
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 17: MAE = 0.00933
# Iteration 18: MAE = 0.00809
# Iteration 19: MAE = 0.00764
# Iteration 20: MAE = 0.00756
# Iteration 21: MAE = 0.00721
# Iteration 22: MAE = 0.00659
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 23: MAE = 0.00648
# Iteration 24: MAE = 0.00635
# Iteration 25: MAE = 0.00624
# Iteration 26: MAE = 0.00624
# Iteration 27: MAE = 0.00619
# Iteration 28: MAE = 0.00611
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 29: MAE = 0.00611
# Iteration 30: MAE = 0.00611
# Check stopping: MAE = 0.00611, Cov Gradient Stable = False
# Iteration 31: MAE = 0.00611
# Check stopping: MAE = 0.00611, Cov Gradient Stable = False
# Iteration 32: MAE = 0.00615
# Check stopping: MAE = 0.00615, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 33: MAE = 0.00612
# Check stopping: MAE = 0.00612, Cov Gradient Stable = False
# Iteration 34: MAE = 0.00610
# Check stopping: MAE = 0.00610, Cov Gradient Stable = False
# Iteration 35: MAE = 0.00603
# Check stopping: MAE = 0.00603, Cov Gradient Stable = False
# Iteration 36: MAE = 0.00601
# Check stopping: MAE = 0.00601, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 37: MAE = 0.00596
# Check stopping: MAE = 0.00596, Cov Gradient Stable = False
# Iteration 38: MAE = 0.00596
# Check stopping: MAE = 0.00596, Cov Gradient Stable = False
# Iteration 39: MAE = 0.00569
# Check stopping: MAE = 0.00569, Cov Gradient Stable = False
# Iteration 40: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = False
# Iteration 41: MAE = 0.00566
# Check stopping: MAE = 0.00566, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 42: MAE = 0.00473
# Check stopping: MAE = 0.00473, Cov Gradient Stable = False
# Iteration 43: MAE = 0.00473
# Check stopping: MAE = 0.00473, Cov Gradient Stable = False
# Iteration 44: MAE = 0.00474
# Check stopping: MAE = 0.00474, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 45: MAE = 0.00472
# Check stopping: MAE = 0.00472, Cov Gradient Stable = False
# Iteration 46: MAE = 0.00471
# Check stopping: MAE = 0.00471, Cov Gradient Stable = False
# Iteration 47: MAE = 0.00468
# Check stopping: MAE = 0.00468, Cov Gradient Stable = False
# Iteration 48: MAE = 0.00448
# Check stopping: MAE = 0.00448, Cov Gradient Stable = False
# Iteration 49: MAE = 0.00445
# Check stopping: MAE = 0.00445, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 50: MAE = 0.00446
# Check stopping: MAE = 0.00446, Cov Gradient Stable = False
# Iteration 51: MAE = 0.00445
# Check stopping: MAE = 0.00445, Cov Gradient Stable = False
# Iteration 52: MAE = 0.00436
# Check stopping: MAE = 0.00436, Cov Gradient Stable = False
# Iteration 53: MAE = 0.00423
# Check stopping: MAE = 0.00423, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 54: MAE = 0.00423
# Check stopping: MAE = 0.00423, Cov Gradient Stable = False
# Iteration 55: MAE = 0.00423
# Check stopping: MAE = 0.00423, Cov Gradient Stable = False
# Iteration 56: MAE = 0.00423
# Check stopping: MAE = 0.00423, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 57: MAE = 0.00423
# Check stopping: MAE = 0.00423, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 58: MAE = 0.00422
# Check stopping: MAE = 0.00422, Cov Gradient Stable = False
# Iteration 59: MAE = 0.00420
# Check stopping: MAE = 0.00420, Cov Gradient Stable = False
# Iteration 60: MAE = 0.00419
# Check stopping: MAE = 0.00419, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# Iteration 61: MAE = 0.00401
# Check stopping: MAE = 0.00401, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 62: MAE = 0.00378
# Check stopping: MAE = 0.00378, Cov Gradient Stable = False
# Iteration 63: MAE = 0.00378
# Check stopping: MAE = 0.00378, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 64: MAE = 0.00378
# Check stopping: MAE = 0.00378, Cov Gradient Stable = False
# Iteration 65: MAE = 0.00372
# Check stopping: MAE = 0.00372, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 66: MAE = 0.00372
# Check stopping: MAE = 0.00372, Cov Gradient Stable = False
# Iteration 67: MAE = 0.00346
# Check stopping: MAE = 0.00346, Cov Gradient Stable = False
# Iteration 68: MAE = 0.00345
# Check stopping: MAE = 0.00345, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# Iteration 69: MAE = 0.00338
# Check stopping: MAE = 0.00338, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 70: MAE = 0.00337
# Check stopping: MAE = 0.00337, Cov Gradient Stable = False
# Iteration 71: MAE = 0.00336
# Check stopping: MAE = 0.00336, Cov Gradient Stable = False
# Iteration 72: MAE = 0.00336
# Check stopping: MAE = 0.00336, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 73: MAE = 0.00336
# Check stopping: MAE = 0.00336, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 74: MAE = 0.00336
# Check stopping: MAE = 0.00336, Cov Gradient Stable = False
# Iteration 75: MAE = 0.00335
# Check stopping: MAE = 0.00335, Cov Gradient Stable = False
# Iteration 76: MAE = 0.00336
# Check stopping: MAE = 0.00336, Cov Gradient Stable = False
# Iteration 77: MAE = 0.00336
# Check stopping: MAE = 0.00336, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 78: MAE = 0.00332
# Check stopping: MAE = 0.00332, Cov Gradient Stable = False
# Iteration 79: MAE = 0.00321
# Check stopping: MAE = 0.00321, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# Iteration 80: MAE = 0.00319
# Check stopping: MAE = 0.00319, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 81: MAE = 0.00316
# Check stopping: MAE = 0.00316, Cov Gradient Stable = False
# Iteration 82: MAE = 0.00304
# Check stopping: MAE = 0.00304, Cov Gradient Stable = False
# Iteration 83: MAE = 0.00302
# Check stopping: MAE = 0.00302, Cov Gradient Stable = False
# Iteration 84: MAE = 0.00302
# Check stopping: MAE = 0.00302, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# Iteration 85: MAE = 0.00301
# Check stopping: MAE = 0.00301, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 86: MAE = 0.00301
# Check stopping: MAE = 0.00301, Cov Gradient Stable = False
# Iteration 87: MAE = 0.00301
# Check stopping: MAE = 0.00301, Cov Gradient Stable = False
# Iteration 88: MAE = 0.00301
# Check stopping: MAE = 0.00301, Cov Gradient Stable = False
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# reconstraining parameters GP_regression
# Iteration 89: MAE = 0.00301
# Check stopping: MAE = 0.00301, Cov Gradient Stable = False
# Iteration 90: MAE = 0.00301
# Check stopping: MAE = 0.00301, Cov Gradient Stable = False
# Iteration 91: MAE = 0.00296
# Check stopping: MAE = 0.00296, Cov Gradient Stable = False
# Iteration 92: MAE = 0.00296
# Check stopping: MAE = 0.00296, Cov Gradient Stable = True
# Stopping criteria met: MAE ≤ 0.005 and covariance stabilized.
# Stopping early at iteration 92 due to stopping condition.
# Results saved to: C:\Users\doaam\Downloads\PhD\Cold active learning\multimodal_active_learning_ccss_main_paper\data\results\evenly_spaced_points\Uncertainty\10311_Au-Pd-Pt-Rh-Ru_RT
